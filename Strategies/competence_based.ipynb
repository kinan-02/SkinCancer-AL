# %%
import pandas as pd
import numpy as np
import pickle
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from scipy.stats import entropy
from collections import defaultdict
import argparse
from matplotlib import pyplot as plt
import random
import torch
random.seed(0) # Set seed for NumPy
np.random.seed(0) # Set seed for PyTorch (for both CPU and GPU)
torch.manual_seed(0)
if torch.cuda.is_available(): 
    torch.cuda.manual_seed_all(0)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

train_df = pd.read_csv('train_dataset/metadata.csv')
test_df = pd.read_csv('test_dataset/metadata.csv')
val_df = pd.read_csv('validation_dataset/metadata.csv')

# %%
print(train_df['diagnosis'].value_counts())
# Out:
# diagnosis
# nevus                         1205
# melanoma                      1113
# pigmented benign keratosis    1099
# basal cell carcinoma           514
# squamous cell carcinoma        197
# vascular lesion                142
# actinic keratosis              130
# dermatofibroma                 115
# Name: count, dtype: int64

# %%
class_mapping = {
    "actinic keratosis": 0,
    "basal cell carcinoma": 1,
    "dermatofibroma": 2,
    "melanoma": 3,
    "nevus": 4,
    "pigmented benign keratosis": 5,
    "squamous cell carcinoma": 6,
    "vascular lesion":7
}
class_mapping
# Out:
# {'actinic keratosis': 0,
#  'basal cell carcinoma': 1,
#  'dermatofibroma': 2,
#  'melanoma': 3,
#  'nevus': 4,
#  'pigmented benign keratosis': 5,
#  'squamous cell carcinoma': 6,
#  'vascular lesion': 7}

# %%
from PIL import Image
import os

import torchvision.transforms as transforms

# Define image transformations (resize, convert to tensor, and normalize)
transform = transforms.Compose([
    transforms.Resize((224, 224)),          # Resize images to 224x224 (matching ResNet input size)
    transforms.ToTensor()
])

class Dataset():
    def __init__(self, dataframe, transform, train='train'):
        self.dataframe=dataframe
        self.train = train
        self.transform = transform
        self.path_to_image=self._create_path_to_image_dict()
        self.paths=list(self.path_to_image.keys())
        self.labels=list(self.path_to_image.values())

    def _create_path_to_image_dict(self):
      path_to_image={}
      for index,row in self.dataframe.iterrows():
        if self.train == 'train':
          img_path = os.path.join('train_dataset/',row['isic_id']+'.jpg')
        elif self.train == 'test':
          img_path = os.path.join('test_dataset/',row['isic_id']+'.jpg')
        else:
            img_path = os.path.join('validation_dataset/',row['isic_id']+'.jpg')
        label=row['diagnosis']
        path_to_image[img_path]=label
      return path_to_image

    def __len__(self):
        return len(self.paths)

    def __getitem__(self,index):
        img_path=self.paths[index]
        img_label=self.labels[index]
        image=Image.open(img_path)
        image=self.transform(image)
        if self.train == 'val':
            return image, class_mapping[img_label], index
        return image, img_label, index

# %%
train_df = Dataset(train_df, transform)
val_df = Dataset(val_df, transform,train='val')
test_df = Dataset(test_df, transform,train='test')

# %%
import torch
import torch.nn as nn
import torchvision.models as models
from torchvision import transforms
from torch.optim import Adam

# Load pre-trained ResNet50 model from torchvision
base_model = models.resnet50(pretrained=True)

num_classes = 8  # Adjust this based on your dataset
base_model.fc = nn.Sequential(
    nn.Flatten(),
    nn.Linear(base_model.fc.in_features, 128),  # Add a fully connected layer
    nn.ReLU(),
    nn.Linear(128, num_classes),  # Final layer with number of classes
    nn.Softmax(dim=1)  # Softmax activation for multi-class classification
)

for param in base_model.parameters():
    param.requires_grad = False  # Freeze all layers except the fully connected ones

# Unfreeze the final fully connected layer
for param in base_model.fc.parameters():
    param.requires_grad = True
    
# class_weights = torch.tensor([0.5, 2.0, 1.0, 0.8, 0.2, 3.0, 0.7, 1.2]).to(device)
loss_f = nn.CrossEntropyLoss()
optimizer = Adam(base_model.fc.parameters(), lr=0.0008)

# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
base_model.to(device)
x = 5
# Out:
# /anaconda/envs/py38_default/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /anaconda/envs/py38_default/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
from torch.utils.data import DataLoader, TensorDataset

batch_size = 4  # Adjust based on your memory and hardware
val_loader = DataLoader(val_df, batch_size=batch_size, shuffle=False)

# %%
class ActiveLearningPipeline:
    def __init__(self, model,
                 available_pool_indices,
                 train_indices,
                 test_indices,
                 selection_criterion,
                 iterations,
                 budget_per_iter,
                 num_epochs):
        self.model = model
        self.iterations = iterations
        self.budget_per_iter = budget_per_iter
        self.available_pool_indices = available_pool_indices
        self.train_indices = train_indices
        self.test_indices = test_indices
        self.selection_criterion = selection_criterion
        if self.selection_criterion == 'random':
          self.train_indices = []
        self.num_epochs = num_epochs
        # self.best_acc = 0

    def run_pipeline(self):
        """
        Run the active learning pipeline
        :return
        accuracy_scores: list, accuracy scores at each iteration
        """
        accuracy_scores = []
        for iteration in range(self.iterations):
            print(f"--------- Number of Iteration {iteration} ---------")
            if self.selection_criterion == 'random':
                self._random_sampling()
            elif self.selection_criterion == 'competence_based':
                self._competence_based_sampling(iteration+1)
            else:
              self._custom_sampling(iteration)
            
            train_images = [train_df.__getitem__(index)[0] for index in self.train_indices]
            label_df = [class_mapping[train_df.__getitem__(index)[1]] for index in self.train_indices]
            self._train_model(train_images, label_df)
            self.model.load_state_dict(torch.load(f"best_{self.selection_criterion}_model.pth"))
            accuracy = self._evaluate_model()
            accuracy_scores.append(accuracy)
        return accuracy_scores
        
    def calculate_class_weights(self, label_counts, num_classes=8):
        total_samples = sum(label_counts.values())
        class_weights = torch.zeros(num_classes)
        
        for cls in range(num_classes):
            if cls in label_counts:
                class_weights[cls] = total_samples / (num_classes * label_counts[cls])
            else:
                class_weights[cls] = 1.0  # Handle the case where a class has zero samples in the current epoch
    
        return class_weights
    
    def _train_model(self, train_images, label_df):
      label_counts = defaultdict(int)
      for label in label_df:
                label_counts[label] += 1
      class_weights = self.calculate_class_weights(label_counts, 8).to(device)
      loss_f = nn.CrossEntropyLoss(weight=class_weights)
        
      train_images_tensor = torch.stack(train_images)
      label_df_tensor = torch.tensor(label_df)
      train_dataset = TensorDataset(train_images_tensor, label_df_tensor)

      batch_size = 32
      train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
      best_acc = 0
      for epoch in range(self.num_epochs):
                self.model.train()
                running_loss = 0.0  # Track the running loss
                correct_predictions = 0
                total_predictions = 0
                # Training loop
                for inputs, labels in train_loader:
                    inputs = inputs
                    inputs= inputs.to(device)
                    labels = torch.tensor(labels).to(device)
                    
                    # Zero the parameter gradients
                    optimizer.zero_grad()

                    # Forward pass
                    outputs = self.model(inputs)
                    # outputs = outputs.logits
                    loss = loss_f(outputs, labels)

                    # Backward pass and optimization
                    loss.backward()
                    optimizer.step()

                    running_loss += loss.item()
        
                    # Calculate accuracy
                    _, preds = torch.max(outputs, 1)
                    correct_predictions += torch.sum(preds == labels)
                    total_predictions += inputs.shape[0]

                # Print loss and accuracy at the end of each epoch
                epoch_loss = running_loss / len(train_loader)
                epoch_acc = correct_predictions.double() / total_predictions
                print(f'Epoch [{epoch+1}/{self.num_epochs}], Loss: {epoch_loss:.4f}, Accuracy: {epoch_acc:.4f}')
          
                val_acc = self._check_model()
                if val_acc > best_acc: 
                    best_acc = val_acc
                    torch.save(self.model.state_dict(), f"best_{self.selection_criterion}_model.pth")
      print("--"*30)
        
    def _check_model(self):
        self.model.eval()
        running_corrects = 0
        total_predictions = 0.0
    
        with torch.no_grad():
            for inputs, labels, _ in val_loader:
                inputs = inputs.to(device)
                labels = torch.tensor(labels).to(device)

                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)

                running_corrects += torch.sum(preds == labels)
                total_predictions += inputs.shape[0]
        val_acc = running_corrects.double() / total_predictions
        return val_acc.item()
        
    def _evaluate_model(self):
        """
        Evaluate the model
        :return:
        accuracy: float, accuracy of the model
        """
        self.model.eval()
        running_corrects = 0
        test_images_tensor = torch.stack(test_images)
        label_df_tensor = torch.tensor(test_label_df)
        test_dataset = TensorDataset(test_images_tensor, label_df_tensor)
        batch_size = 32  # Adjust based on your memory and hardware
        test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
        total_predictions = 0.0
        with torch.no_grad():
            for inputs, labels in test_loader:
                inputs = inputs.to(device)
                labels = torch.tensor(labels).to(device)

                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)

                running_corrects += torch.sum(preds == labels)
                total_predictions += inputs.shape[0]
        test_acc = running_corrects.double() / total_predictions
        return test_acc.item()

    def _random_sampling(self):
      selected_indices = np.random.choice(self.available_pool_indices, self.budget_per_iter, replace=False)
      selected_indices = selected_indices.tolist()
      self.train_indices = self.train_indices + selected_indices

      available_pool_set = set(self.available_pool_indices)
      train_set = set(self.train_indices)
      self.available_pool_indices = list(available_pool_set - train_set)
        
    def _competence_based_sampling(self, itr):
      model = self.model
      
      X_unlabeled = [train_df.__getitem__(index)[0] for index in self.available_pool_indices]
      
      pool_images_tensor = torch.stack(X_unlabeled)
      pool_dataset = TensorDataset(pool_images_tensor)
    
      batch_size = 32
      pool_loader = DataLoader(pool_dataset, batch_size=batch_size, shuffle=False)
      model.eval()
      outputs = []
      with torch.no_grad():
                for inputs in pool_loader:
                    inputs = inputs[0]
                    inputs = inputs.to(device)
                    x = model(inputs)
                    if x.shape[0] != batch_size:
                        padding_tensor = torch.full((batch_size - x.shape[0], 8), 0).to(device)
                        c = batch_size - x.shape[0]
                        x = torch.cat([x, padding_tensor])
                    else:
                        outputs.append(x)
      probabilities = torch.cat(outputs, dim=0)
      probabilities = probabilities[:-c]
      probabilities_cpu = probabilities.cpu().numpy()
      p_scores = []
      for prob in probabilities_cpu:
         max_prob = np.max(prob)  
         p_score = (1 - max_prob)
         p_scores.append(p_score)
          
      p_scores = np.array(p_scores)
      cdf = np.cumsum(p_scores) / np.sum(p_scores)
    
      C0 = 0.5
      c_t = min(1, np.sqrt((itr / self.iterations) * (1 - C0**2) / self.iterations + C0**2))

      selected_indices = np.where(p_scores > c_t)[0]
      # print(selected_indices.shape)
        
      if len(selected_indices) > 0:
        if selected_indices.shape[0] < self.budget_per_iter:
            sampled_indices = selected_indices.tolist()
            sorted_p_scores_indices = np.argsort(p_scores)
            remaining_indices = np.setdiff1d(sorted_p_scores_indices, selected_indices)
            additional_samples = remaining_indices[:self.budget_per_iter - len(selected_indices)]
            sampled_indices.extend(additional_samples)
        else:
            selected_cdf_values = cdf[selected_indices]
            selected_cdf_norm = selected_cdf_values / np.sum(selected_cdf_values)
            sampled_indices = np.random.choice(selected_indices, self.budget_per_iter, p=selected_cdf_norm, replace=False)
      else:
        sampled_indices = np.random.choice(len(p_scores), self.budget_per_iter, replace=False)
    
      temp = np.array(self.available_pool_indices)
      selected_indices = temp[sampled_indices]

      self.train_indices = self.train_indices + selected_indices.tolist()

      available_pool_set = set(self.available_pool_indices)
      train_set = set(self.train_indices)
      self.available_pool_indices = list(available_pool_set - train_set)

# %%
def generate_plot(accuracy_scores_dict):
    """
    Generate a plot
    """
    for criterion, accuracy_scores in accuracy_scores_dict.items():
        plt.plot(range(1, len(accuracy_scores) + 1), accuracy_scores, label=criterion)
    plt.xlabel('Iterations')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

# %%
available_pool_indices = []
for i in range(len(train_df)):
    image, label, index = train_df[i]
    available_pool_indices.append(index)

test_indices = []
for i in range(len(test_df)):
    image, label, index = test_df[i]
    test_indices.append(index)
test_images = [test_df.__getitem__(index)[0] for index in test_indices]
test_label_df = [class_mapping[test_df.__getitem__(index)[1]] for index in test_indices]

# %%
train_indices = [1372,
 1277,
 1255,
 1423,
 2925,
 1963,
 2335,
 1923,
 3791,
 1239,
 909,
 134,
 1547,
 3931,
 2467,
 2832,
 1789,
 3022,
 2424,
 780,
 2412,
 3038,
 2158,
 3335,
 1868,
 1771,
 2015,
 1535,
 710,
 3007]
available_pool_set = set(available_pool_indices)
train_set = set(train_indices)
available_pool_indices = list(available_pool_set - train_set)

# %%
iterations = 20
budget_per_iter = 60 # 30
num_epoch = 30
selection_criteria = ['competence_based'] # competence_based_30
accuracy_scores_dict = defaultdict(list)
model = base_model

# %%
for criterion in selection_criteria:
    AL_class = ActiveLearningPipeline(model=model,
                                      test_indices=test_indices,
                                      available_pool_indices=available_pool_indices,
                                      train_indices=train_indices,
                                      selection_criterion=criterion,
                                      iterations=iterations,
                                      budget_per_iter=budget_per_iter,
                                      num_epochs=num_epoch)
    accuracy_scores_dict[criterion] = AL_class.run_pipeline()
generate_plot(accuracy_scores_dict)
# Out:
# --------- Number of Iteration 0 ---------
# /tmp/ipykernel_27507/3275052546.py:81: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   labels = torch.tensor(labels).to(device)
# Epoch [1/30], Loss: 2.0956, Accuracy: 0.0667
# /tmp/ipykernel_27507/3275052546.py:121: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   labels = torch.tensor(labels).to(device)
# Epoch [2/30], Loss: 2.0622, Accuracy: 0.1556
# Epoch [3/30], Loss: 2.0349, Accuracy: 0.4556
# Epoch [4/30], Loss: 2.0089, Accuracy: 0.4444
# Epoch [5/30], Loss: 1.9870, Accuracy: 0.3667
# Epoch [6/30], Loss: 1.9414, Accuracy: 0.5111
# Epoch [7/30], Loss: 1.9152, Accuracy: 0.6000
# Epoch [8/30], Loss: 1.8834, Accuracy: 0.6556
# Epoch [9/30], Loss: 1.8540, Accuracy: 0.7444
# Epoch [10/30], Loss: 1.8213, Accuracy: 0.7889
# Epoch [11/30], Loss: 1.7618, Accuracy: 0.7444
# Epoch [12/30], Loss: 1.6973, Accuracy: 0.7556
# Epoch [13/30], Loss: 1.6628, Accuracy: 0.7667
# Epoch [14/30], Loss: 1.6089, Accuracy: 0.8000
# Epoch [15/30], Loss: 1.6041, Accuracy: 0.7889
# Epoch [16/30], Loss: 1.5680, Accuracy: 0.8333
# Epoch [17/30], Loss: 1.5240, Accuracy: 0.8000
# Epoch [18/30], Loss: 1.5304, Accuracy: 0.8333
# Epoch [20/30], Loss: 1.4347, Accuracy: 0.8156
# Epoch [21/30], Loss: 1.4380, Accuracy: 0.8311
# Epoch [22/30], Loss: 1.5599, Accuracy: 0.6178
# Epoch [23/30], Loss: 1.5443, Accuracy: 0.6600
# Epoch [24/30], Loss: 1.4500, Accuracy: 0.8400
# Epoch [25/30], Loss: 1.4530, Accuracy: 0.8133
# Epoch [26/30], Loss: 1.5254, Accuracy: 0.7067
# Epoch [27/30], Loss: 1.4917, Accuracy: 0.7978
# Epoch [28/30], Loss: 1.5583, Accuracy: 0.6956
# Epoch [29/30], Loss: 1.5185, Accuracy: 0.6489
# Epoch [30/30], Loss: 1.5243, Accuracy: 0.6889
# ------------------------------------------------------------
# --------- Number of Iteration 7 ---------
# Epoch [1/30], Loss: 1.5106, Accuracy: 0.7431
# Epoch [2/30], Loss: 1.4856, Accuracy: 0.7843
# Epoch [3/30], Loss: 1.4942, Accuracy: 0.7608
# Epoch [4/30], Loss: 1.4966, Accuracy: 0.7765
# Epoch [5/30], Loss: 1.4742, Accuracy: 0.7804
# Epoch [6/30], Loss: 1.4767, Accuracy: 0.7843
# Epoch [7/30], Loss: 1.4651, Accuracy: 0.7882
# Epoch [8/30], Loss: 1.4597, Accuracy: 0.8176
# Epoch [9/30], Loss: 1.4521, Accuracy: 0.8098
# Epoch [10/30], Loss: 1.4565, Accuracy: 0.7941
# Epoch [11/30], Loss: 1.4475, Accuracy: 0.8216
# Epoch [12/30], Loss: 1.4363, Accuracy: 0.8392
# Epoch [13/30], Loss: 1.4308, Accuracy: 0.8490
# Epoch [14/30], Loss: 1.4279, Accuracy: 0.8314
# Epoch [15/30], Loss: 1.4575, Accuracy: 0.8078
# Epoch [16/30], Loss: 1.4310, Accuracy: 0.8294
# Epoch [17/30], Loss: 1.4240, Accuracy: 0.8451
# Epoch [18/30], Loss: 1.4332, Accuracy: 0.8353
# Epoch [19/30], Loss: 1.4367, Accuracy: 0.8176
# Epoch [20/30], Loss: 1.4389, Accuracy: 0.8275
# Epoch [21/30], Loss: 1.4311, Accuracy: 0.8235
# Epoch [22/30], Loss: 1.4299, Accuracy: 0.8392
# Epoch [23/30], Loss: 1.4160, Accuracy: 0.8647
# Epoch [24/30], Loss: 1.4107, Accuracy: 0.8471
# Epoch [25/30], Loss: 1.4152, Accuracy: 0.8471
# Epoch [26/30], Loss: 1.4038, Accuracy: 0.8667
# Epoch [27/30], Loss: 1.4162, Accuracy: 0.8588
# Epoch [28/30], Loss: 1.4080, Accuracy: 0.8549
# Epoch [29/30], Loss: 1.4242, Accuracy: 0.8373
# Epoch [30/30], Loss: 1.4455, Accuracy: 0.7922
# ------------------------------------------------------------
# --------- Number of Iteration 8 ---------
# Epoch [1/30], Loss: 1.5190, Accuracy: 0.7053
# Epoch [2/30], Loss: 1.4762, Accuracy: 0.7947
# Epoch [3/30], Loss: 1.4954, Accuracy: 0.7596
# Epoch [4/30], Loss: 1.4756, Accuracy: 0.7719
# Epoch [22/30], Loss: 1.4445, Accuracy: 0.8123
# Epoch [23/30], Loss: 1.4747, Accuracy: 0.7840
# Epoch [24/30], Loss: 1.4688, Accuracy: 0.7778
# Epoch [25/30], Loss: 1.4504, Accuracy: 0.8012
# Epoch [26/30], Loss: 1.4363, Accuracy: 0.8037
# Epoch [27/30], Loss: 1.4501, Accuracy: 0.8123
# Epoch [28/30], Loss: 1.4577, Accuracy: 0.7963
# Epoch [29/30], Loss: 1.4784, Accuracy: 0.7741
# Epoch [30/30], Loss: 1.4809, Accuracy: 0.7642
# ------------------------------------------------------------
# --------- Number of Iteration 13 ---------
# Epoch [1/30], Loss: 1.4870, Accuracy: 0.7471
# Epoch [2/30], Loss: 1.4853, Accuracy: 0.7828
# Epoch [3/30], Loss: 1.5132, Accuracy: 0.7080
# Epoch [4/30], Loss: 1.4905, Accuracy: 0.7414
# Epoch [5/30], Loss: 1.4776, Accuracy: 0.7632
# Epoch [6/30], Loss: 1.4853, Accuracy: 0.7690
# Epoch [7/30], Loss: 1.4753, Accuracy: 0.7713
# Epoch [8/30], Loss: 1.5107, Accuracy: 0.7356
# Epoch [9/30], Loss: 1.4702, Accuracy: 0.7851
# Epoch [10/30], Loss: 1.4552, Accuracy: 0.7701
# Epoch [11/30], Loss: 1.4586, Accuracy: 0.7943
# Epoch [12/30], Loss: 1.4662, Accuracy: 0.7897
# Epoch [13/30], Loss: 1.4567, Accuracy: 0.7954
# Epoch [14/30], Loss: 1.5683, Accuracy: 0.5954
# Epoch [15/30], Loss: 1.5565, Accuracy: 0.6230
# Epoch [16/30], Loss: 1.5785, Accuracy: 0.5759
# Epoch [17/30], Loss: 1.5533, Accuracy: 0.6253
# Epoch [18/30], Loss: 1.5498, Accuracy: 0.6391
# Epoch [19/30], Loss: 1.5130, Accuracy: 0.6667
# Epoch [20/30], Loss: 1.4750, Accuracy: 0.7644
# Epoch [21/30], Loss: 1.4561, Accuracy: 0.8034
# Epoch [22/30], Loss: 1.4635, Accuracy: 0.8149
# Epoch [23/30], Loss: 1.4593, Accuracy: 0.7874
# Epoch [24/30], Loss: 1.4433, Accuracy: 0.8080
# Epoch [25/30], Loss: 1.4554, Accuracy: 0.7851
# Epoch [26/30], Loss: 1.4848, Accuracy: 0.7448
# Epoch [27/30], Loss: 1.4579, Accuracy: 0.8023
# Epoch [28/30], Loss: 1.4586, Accuracy: 0.7816
# Epoch [29/30], Loss: 1.4651, Accuracy: 0.7862
# Epoch [30/30], Loss: 1.4929, Accuracy: 0.7345
# ------------------------------------------------------------
# --------- Number of Iteration 14 ---------
# Epoch [1/30], Loss: 1.4913, Accuracy: 0.7688
# Epoch [2/30], Loss: 1.4762, Accuracy: 0.7753
# Epoch [3/30], Loss: 1.5965, Accuracy: 0.5742
# Epoch [4/30], Loss: 1.5305, Accuracy: 0.6527
# Epoch [5/30], Loss: 1.4645, Accuracy: 0.7806
# Epoch [6/30], Loss: 1.4829, Accuracy: 0.7946
# Epoch [7/30], Loss: 1.4937, Accuracy: 0.7742
# Epoch [8/30], Loss: 1.4560, Accuracy: 0.8151
# Epoch [9/30], Loss: 1.5824, Accuracy: 0.5817
# Epoch [10/30], Loss: 1.5544, Accuracy: 0.5968
# Epoch [11/30], Loss: 1.5666, Accuracy: 0.6118
# Epoch [12/30], Loss: 1.5283, Accuracy: 0.6183
# Epoch [13/30], Loss: 1.5306, Accuracy: 0.6118
# Epoch [14/30], Loss: 1.5096, Accuracy: 0.6860
# Epoch [15/30], Loss: 1.5651, Accuracy: 0.5935
# Epoch [16/30], Loss: 1.6738, Accuracy: 0.4602
# Epoch [17/30], Loss: 1.5693, Accuracy: 0.5989
# Epoch [18/30], Loss: 1.5671, Accuracy: 0.5688
# Epoch [19/30], Loss: 1.5453, Accuracy: 0.6151
# Epoch [20/30], Loss: 1.5877, Accuracy: 0.5452
# Epoch [21/30], Loss: 1.5242, Accuracy: 0.6258
# Epoch [22/30], Loss: 1.5705, Accuracy: 0.5957
# Epoch [23/30], Loss: 1.5287, Accuracy: 0.6129
# Epoch [24/30], Loss: 1.5468, Accuracy: 0.6237
# Epoch [25/30], Loss: 1.5474, Accuracy: 0.6333
# Epoch [26/30], Loss: 1.5419, Accuracy: 0.6000
# Epoch [27/30], Loss: 1.5453, Accuracy: 0.6183
# Epoch [28/30], Loss: 1.5289, Accuracy: 0.6559
# Epoch [29/30], Loss: 1.4973, Accuracy: 0.7484
# Epoch [30/30], Loss: 1.4895, Accuracy: 0.7645
# ------------------------------------------------------------
# --------- Number of Iteration 15 ---------
# Epoch [1/30], Loss: 1.4927, Accuracy: 0.7636
# Epoch [2/30], Loss: 1.4958, Accuracy: 0.7616
# Epoch [3/30], Loss: 1.5034, Accuracy: 0.7525
# Epoch [4/30], Loss: 1.4822, Accuracy: 0.7758
# Epoch [5/30], Loss: 1.4793, Accuracy: 0.7747
# Epoch [6/30], Loss: 1.4849, Accuracy: 0.7697
# Epoch [7/30], Loss: 1.4844, Accuracy: 0.7727
# Epoch [8/30], Loss: 1.4869, Accuracy: 0.7586
# Epoch [9/30], Loss: 1.4661, Accuracy: 0.8061
# Epoch [10/30], Loss: 1.4659, Accuracy: 0.7818
# Epoch [11/30], Loss: 1.4748, Accuracy: 0.7879
# Epoch [12/30], Loss: 1.4683, Accuracy: 0.7990
# Epoch [13/30], Loss: 1.4881, Accuracy: 0.7606
# Epoch [14/30], Loss: 1.4735, Accuracy: 0.7788
# Epoch [15/30], Loss: 1.4649, Accuracy: 0.7838
# Epoch [16/30], Loss: 1.4774, Accuracy: 0.7586
# Epoch [17/30], Loss: 1.4690, Accuracy: 0.7828
# Epoch [18/30], Loss: 1.4771, Accuracy: 0.7717
# Epoch [19/30], Loss: 1.4611, Accuracy: 0.8091
# Epoch [20/30], Loss: 1.4587, Accuracy: 0.8081
# Epoch [21/30], Loss: 1.4397, Accuracy: 0.8192
# Epoch [22/30], Loss: 1.4450, Accuracy: 0.8111
# Epoch [23/30], Loss: 1.4406, Accuracy: 0.8192
# Epoch [24/30], Loss: 1.4338, Accuracy: 0.8273
# Epoch [25/30], Loss: 1.4495, Accuracy: 0.8182
# Epoch [26/30], Loss: 1.4578, Accuracy: 0.7939
# Epoch [27/30], Loss: 1.4436, Accuracy: 0.8162
# Epoch [28/30], Loss: 1.4402, Accuracy: 0.8202
# Epoch [29/30], Loss: 1.4210, Accuracy: 0.8444
# Epoch [30/30], Loss: 1.4452, Accuracy: 0.8010
# ------------------------------------------------------------
# --------- Number of Iteration 16 ---------
# Epoch [1/30], Loss: 1.4900, Accuracy: 0.7686
# Epoch [2/30], Loss: 1.4854, Accuracy: 0.7667
# Epoch [3/30], Loss: 1.4881, Accuracy: 0.7562
# Epoch [4/30], Loss: 1.4862, Accuracy: 0.7790
# Epoch [5/30], Loss: 1.4966, Accuracy: 0.7638
# Epoch [6/30], Loss: 1.4707, Accuracy: 0.7695
# Epoch [7/30], Loss: 1.4578, Accuracy: 0.8124
# Epoch [8/30], Loss: 1.4725, Accuracy: 0.7857
# Epoch [9/30], Loss: 1.4625, Accuracy: 0.7924
# Epoch [10/30], Loss: 1.4591, Accuracy: 0.8114
# Epoch [11/30], Loss: 1.4783, Accuracy: 0.7752
# Epoch [12/30], Loss: 1.4533, Accuracy: 0.7943
# Epoch [13/30], Loss: 1.4754, Accuracy: 0.7705
# Epoch [14/30], Loss: 1.4882, Accuracy: 0.7676
# Epoch [15/30], Loss: 1.4438, Accuracy: 0.8057
# Epoch [16/30], Loss: 1.4531, Accuracy: 0.7943
# Epoch [17/30], Loss: 1.4369, Accuracy: 0.8333
# Epoch [18/30], Loss: 1.4441, Accuracy: 0.8219
# Epoch [19/30], Loss: 1.4679, Accuracy: 0.7790
# Epoch [20/30], Loss: 1.4609, Accuracy: 0.7810
# Epoch [21/30], Loss: 1.4582, Accuracy: 0.8124
# Epoch [22/30], Loss: 1.4470, Accuracy: 0.8086
# Epoch [23/30], Loss: 1.4369, Accuracy: 0.8276
# Epoch [24/30], Loss: 1.4404, Accuracy: 0.8162
# Epoch [25/30], Loss: 1.4502, Accuracy: 0.8105
# Epoch [26/30], Loss: 1.4376, Accuracy: 0.8267
# Epoch [27/30], Loss: 1.4282, Accuracy: 0.8314
# Epoch [28/30], Loss: 1.4341, Accuracy: 0.8381
# Epoch [29/30], Loss: 1.4300, Accuracy: 0.8400
# Epoch [30/30], Loss: 1.4319, Accuracy: 0.8267
# ------------------------------------------------------------
# --------- Number of Iteration 17 ---------
# Epoch [1/30], Loss: 1.4936, Accuracy: 0.7568
# Epoch [2/30], Loss: 1.5010, Accuracy: 0.7586
# Epoch [3/30], Loss: 1.5194, Accuracy: 0.7270
# Epoch [4/30], Loss: 1.4980, Accuracy: 0.7568
# Epoch [5/30], Loss: 1.4951, Accuracy: 0.7757
# Epoch [6/30], Loss: 1.4840, Accuracy: 0.7793
# Epoch [7/30], Loss: 1.4756, Accuracy: 0.7775
# Epoch [8/30], Loss: 1.4930, Accuracy: 0.7559
# Epoch [9/30], Loss: 1.4684, Accuracy: 0.7919
# Epoch [10/30], Loss: 1.4686, Accuracy: 0.7856
# Epoch [11/30], Loss: 1.4863, Accuracy: 0.7613
# Epoch [12/30], Loss: 1.4511, Accuracy: 0.8000
# Epoch [13/30], Loss: 1.4872, Accuracy: 0.7441
# Epoch [14/30], Loss: 1.4773, Accuracy: 0.7793
# Epoch [15/30], Loss: 1.4566, Accuracy: 0.8171
# Epoch [16/30], Loss: 1.4537, Accuracy: 0.8135
# Epoch [17/30], Loss: 1.4606, Accuracy: 0.7928
# Epoch [18/30], Loss: 1.4673, Accuracy: 0.7865
# Epoch [19/30], Loss: 1.4545, Accuracy: 0.7991
# Epoch [20/30], Loss: 1.4529, Accuracy: 0.8045
# Epoch [21/30], Loss: 1.4520, Accuracy: 0.7883
# Epoch [22/30], Loss: 1.4571, Accuracy: 0.8036
# Epoch [23/30], Loss: 1.4539, Accuracy: 0.7973
# Epoch [24/30], Loss: 1.4419, Accuracy: 0.8180
# Epoch [25/30], Loss: 1.4422, Accuracy: 0.8252
# Epoch [26/30], Loss: 1.4415, Accuracy: 0.8090
# Epoch [27/30], Loss: 1.4469, Accuracy: 0.8135
# Epoch [28/30], Loss: 1.4409, Accuracy: 0.8126
# Epoch [29/30], Loss: 1.4356, Accuracy: 0.8270
# Epoch [30/30], Loss: 1.4293, Accuracy: 0.8333
# ------------------------------------------------------------
# --------- Number of Iteration 18 ---------
# Epoch [1/30], Loss: 1.4713, Accuracy: 0.7932
# Epoch [2/30], Loss: 1.4650, Accuracy: 0.8026
# Epoch [3/30], Loss: 1.4435, Accuracy: 0.8205
# Epoch [4/30], Loss: 1.4666, Accuracy: 0.7949
# Epoch [5/30], Loss: 1.4650, Accuracy: 0.7846
# Epoch [6/30], Loss: 1.4721, Accuracy: 0.7667
# Epoch [7/30], Loss: 1.4555, Accuracy: 0.8085
# Epoch [8/30], Loss: 1.4533, Accuracy: 0.8043
# Epoch [9/30], Loss: 1.4391, Accuracy: 0.8162
# Epoch [10/30], Loss: 1.4579, Accuracy: 0.8017
# Epoch [11/30], Loss: 1.4541, Accuracy: 0.8026
# Epoch [12/30], Loss: 1.4560, Accuracy: 0.7966
# Epoch [13/30], Loss: 1.4409, Accuracy: 0.8179
# Epoch [14/30], Loss: 1.4561, Accuracy: 0.8103
# Epoch [15/30], Loss: 1.4450, Accuracy: 0.8197
# Epoch [16/30], Loss: 1.4308, Accuracy: 0.8350
# Epoch [17/30], Loss: 1.4647, Accuracy: 0.7957
# Epoch [18/30], Loss: 1.4246, Accuracy: 0.8359
# Epoch [19/30], Loss: 1.4187, Accuracy: 0.8462
# Epoch [20/30], Loss: 1.4421, Accuracy: 0.8077
# Epoch [21/30], Loss: 1.4212, Accuracy: 0.8350
# Epoch [22/30], Loss: 1.4491, Accuracy: 0.7923
# Epoch [23/30], Loss: 1.4580, Accuracy: 0.7829
# Epoch [24/30], Loss: 1.4519, Accuracy: 0.8128
# Epoch [25/30], Loss: 1.4317, Accuracy: 0.8179
# Epoch [26/30], Loss: 1.4193, Accuracy: 0.8350
# Epoch [27/30], Loss: 1.4156, Accuracy: 0.8427
# Epoch [28/30], Loss: 1.4075, Accuracy: 0.8556
# Epoch [29/30], Loss: 1.4133, Accuracy: 0.8410
# Epoch [30/30], Loss: 1.4429, Accuracy: 0.8009
# ------------------------------------------------------------
# --------- Number of Iteration 19 ---------
# Epoch [1/30], Loss: 1.4457, Accuracy: 0.8138
# Epoch [2/30], Loss: 1.4616, Accuracy: 0.8041
# Epoch [3/30], Loss: 1.4610, Accuracy: 0.7927
# Epoch [4/30], Loss: 1.4739, Accuracy: 0.7878
# Epoch [5/30], Loss: 1.4788, Accuracy: 0.7821
# Epoch [6/30], Loss: 1.4637, Accuracy: 0.7927
# Epoch [7/30], Loss: 1.4493, Accuracy: 0.8228
# Epoch [8/30], Loss: 1.4450, Accuracy: 0.8179
# Epoch [9/30], Loss: 1.4529, Accuracy: 0.8081
# Epoch [10/30], Loss: 1.4823, Accuracy: 0.7821
# Epoch [11/30], Loss: 1.4677, Accuracy: 0.7919
# Epoch [12/30], Loss: 1.4579, Accuracy: 0.7959
# Epoch [13/30], Loss: 1.4587, Accuracy: 0.8106
# Epoch [14/30], Loss: 1.4567, Accuracy: 0.7959
# Epoch [15/30], Loss: 1.4505, Accuracy: 0.8138
# Epoch [16/30], Loss: 1.4360, Accuracy: 0.8252
# Epoch [17/30], Loss: 1.4426, Accuracy: 0.8236
# Epoch [18/30], Loss: 1.4654, Accuracy: 0.7902
# Epoch [19/30], Loss: 1.4498, Accuracy: 0.8049
# Epoch [20/30], Loss: 1.4515, Accuracy: 0.8171
# Epoch [21/30], Loss: 1.4401, Accuracy: 0.8293
# Epoch [22/30], Loss: 1.4540, Accuracy: 0.7984
# Epoch [23/30], Loss: 1.4452, Accuracy: 0.8065
# Epoch [24/30], Loss: 1.4207, Accuracy: 0.8463
# Epoch [25/30], Loss: 1.4189, Accuracy: 0.8504
# Epoch [26/30], Loss: 1.4370, Accuracy: 0.8211
# Epoch [27/30], Loss: 1.4281, Accuracy: 0.8407
# Epoch [28/30], Loss: 1.4169, Accuracy: 0.8496
# Epoch [29/30], Loss: 1.4210, Accuracy: 0.8390
# Epoch [30/30], Loss: 1.4284, Accuracy: 0.8358
# ------------------------------------------------------------

# %%
accuracy_scores_dict
# Out:
# defaultdict(list,
#             {'competence_based': [0.5634920634920635,
#               0.5899470899470899,
#               0.5873015873015872,
#               0.6144179894179894,
#               0.6078042328042328,
#               0.6521164021164021,
#               0.6190476190476191,
#               0.66005291005291,
#               0.6514550264550264,
#               0.6369047619047619,
#               0.6719576719576719,
#               0.6593915343915343,
#               0.6990740740740741,
#               0.664021164021164,
#               0.6825396825396826,
#               0.6779100529100529,
#               0.6752645502645502,
#               0.6990740740740741,
#               0.6865079365079365,
#               0.6871693121693121]})
