# %%
import pandas as pd
import numpy as np
import pickle
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from scipy.stats import entropy
from collections import defaultdict
import argparse
from matplotlib import pyplot as plt
import random
import torch
random.seed(0) # Set seed for NumPy
np.random.seed(0) # Set seed for PyTorch (for both CPU and GPU)
torch.manual_seed(0)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(0)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

train_df = pd.read_csv('train_dataset/metadata.csv')
test_df = pd.read_csv('test_dataset/metadata.csv')
val_df = pd.read_csv('validation_dataset/metadata.csv')

# %%
print(train_df['diagnosis'].value_counts())
# Out:
# diagnosis
# nevus                         1205
# melanoma                      1113
# pigmented benign keratosis    1099
# basal cell carcinoma           514
# squamous cell carcinoma        197
# vascular lesion                142
# actinic keratosis              130
# dermatofibroma                 115
# Name: count, dtype: int64

# %%
class_mapping = {
    "actinic keratosis": 0,
    "basal cell carcinoma": 1,
    "dermatofibroma": 2,
    "melanoma": 3,
    "nevus": 4,
    "pigmented benign keratosis": 5,
    "squamous cell carcinoma": 6,
    "vascular lesion":7
}
class_mapping
# Out:
# {'actinic keratosis': 0,
#  'basal cell carcinoma': 1,
#  'dermatofibroma': 2,
#  'melanoma': 3,
#  'nevus': 4,
#  'pigmented benign keratosis': 5,
#  'squamous cell carcinoma': 6,
#  'vascular lesion': 7}

# %%
from PIL import Image
import os

import torchvision.transforms as transforms

# Define image transformations (resize, convert to tensor, and normalize)
transform = transforms.Compose([
    transforms.Resize((224, 224)),          # Resize images to 224x224 (matching ResNet input size)
    transforms.ToTensor()
])

class Dataset():
    """
    This class is to read the data and pass an instance of it later to the Dataloader
    """
    def __init__(self, dataframe, transform, train='train'):
        self.dataframe=dataframe
        self.train = train
        self.transform = transform
        self.path_to_image=self._create_path_to_image_dict()
        self.paths=list(self.path_to_image.keys())
        self.labels=list(self.path_to_image.values())

    def _create_path_to_image_dict(self):
      path_to_image={}
      for index,row in self.dataframe.iterrows():
        if self.train == 'train':
          img_path = os.path.join('train_dataset/',row['isic_id']+'.jpg')
        elif self.train == 'test':
          img_path = os.path.join('test_dataset/',row['isic_id']+'.jpg')
        else:
            img_path = os.path.join('validation_dataset/',row['isic_id']+'.jpg')
        label=row['diagnosis']
        path_to_image[img_path]=label
      return path_to_image

    def __len__(self):
        return len(self.paths)

    def __getitem__(self,index):
        img_path=self.paths[index]
        img_label=self.labels[index]
        image=Image.open(img_path)
        image=self.transform(image)
        if self.train == 'val':
            return image, class_mapping[img_label], index
        return image, img_label, index

# %%
train_df = Dataset(train_df, transform)
val_df = Dataset(val_df, transform,train='val')
test_df = Dataset(test_df, transform,train='test')

# %%
import torch
import torch.nn as nn
import torchvision.models as models
from torchvision import transforms
from torch.optim import Adam

# Load pre-trained ResNet50 model from torchvision
base_model = models.resnet50(pretrained=True)

num_classes = 8
#replacing the last fc in the pretrained base model
base_model.fc = nn.Sequential(
    nn.Flatten(),
    nn.Linear(base_model.fc.in_features, 128),  # Add a fully connected layer
    nn.ReLU(),
    nn.Linear(128, num_classes),  # Final layer with number of classes
    nn.Softmax(dim=1)  # Softmax activation for multi-class classification
)

for param in base_model.parameters():
    param.requires_grad = False  # Freeze all layers except the fully connected ones

# Unfreeze the final fully connected layer
for param in base_model.fc.parameters():
    param.requires_grad = True

loss_f = nn.CrossEntropyLoss()
optimizer = Adam(base_model.fc.parameters(), lr=0.0008)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
base_model.to(device)
# Out:
# /anaconda/envs/py38_default/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /anaconda/envs/py38_default/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
from torch.utils.data import DataLoader, TensorDataset

batch_size = 4
val_loader = DataLoader(val_df, batch_size=batch_size, shuffle=False)

# %%
class ActiveLearningPipeline:
    def __init__(self, model,
                 available_pool_indices,
                 train_indices,
                 test_indices,
                 selection_criterion,
                 iterations,
                 budget_per_iter,
                 num_epochs):
        self.model = model
        self.iterations = iterations
        self.budget_per_iter = budget_per_iter
        self.available_pool_indices = available_pool_indices
        self.train_indices = train_indices
        self.test_indices = test_indices
        self.selection_criterion = selection_criterion
        if self.selection_criterion == 'random':
          self.train_indices = []
        self.num_epochs = num_epochs
        # self.best_acc = 0
        self.high_confidence_labels = []
        self.high_confidence_indices = []

    def run_pipeline(self):
        """
        Run the active learning pipeline
        :return
        accuracy_scores: list, accuracy scores at each iteration
        """
        accuracy_scores = []
        confidence_threshold = 0.05
        dr = 0.0033
        for iteration in range(self.iterations):
            print(f"--------- Number of Iteration {iteration} ---------")
            if self.selection_criterion == 'random':
                self._random_sampling()
            elif self.selection_criterion == 'uncertainty_ceal_30':
                #updating threshold
                confidence_threshold -= dr*iteration
                self._uncertainty_ceal_sampling(confidence_threshold)
            else:
              self._custom_sampling(iteration)
            #adding the indices that were sampled according to the CEAL strategy and uncertainty to be the training data of the model
            train_images = [train_df.__getitem__(index)[0] for index in self.train_indices] + [train_df.__getitem__(index)[0] for index in self.high_confidence_indices]
            label_df = [class_mapping[train_df.__getitem__(index)[1]] for index in self.train_indices] + list(self.high_confidence_labels)
            self._train_model(train_images, label_df)
            #loading the best model weights on the validation set in each iteration
            self.model.load_state_dict(torch.load(f"best_{self.selection_criterion}_model.pth"))
            accuracy = self._evaluate_model()
            accuracy_scores.append(accuracy)
        return accuracy_scores

    def calculate_class_weights(self, label_counts, num_classes=8):
        """
        Calculating the inverse of the probability of each class in the dataset
        """
        total_samples = sum(label_counts.values())
        class_weights = torch.zeros(num_classes)

        for cls in range(num_classes):
            if cls in label_counts:
                class_weights[cls] = total_samples / (num_classes * label_counts[cls])
            else:
                class_weights[cls] = 1.0  # Handle the case where a class has zero samples in the current epoch

        return class_weights

    def _train_model(self, train_images, label_df):
      label_counts = defaultdict(int)
      for label in label_df:
                label_counts[label] += 1
      """
        giving higher weight for the loss of samples that their class is a minority in the data while giving less weight
        to the loss for classes that are majority.
      """
      class_weights = self.calculate_class_weights(label_counts, 8).to(device)
      loss_f = nn.CrossEntropyLoss(weight=class_weights)

      train_images_tensor = torch.stack(train_images)
      label_df_tensor = torch.tensor(label_df)
      train_dataset = TensorDataset(train_images_tensor, label_df_tensor)

      batch_size = 32
      train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
      best_acc=0
      for epoch in range(self.num_epochs):
                self.model.train()
                running_loss = 0.0  # Track the running loss
                correct_predictions = 0
                total_predictions = 0
                # Training loop
                for inputs, labels in train_loader:
                    inputs = inputs
                    inputs= inputs.to(device)
                    labels = torch.tensor(labels).to(device)

                    # Zero the parameter gradients
                    optimizer.zero_grad()

                    # Forward pass
                    outputs = self.model(inputs)
                    loss = loss_f(outputs, labels)

                    # Backward pass and optimization
                    loss.backward()
                    optimizer.step()

                    running_loss += loss.item()

                    # Calculate accuracy
                    _, preds = torch.max(outputs, 1)
                    correct_predictions += torch.sum(preds == labels)
                    total_predictions += inputs.shape[0]

                # Print loss and accuracy at the end of each epoch
                epoch_loss = running_loss / len(train_loader)
                epoch_acc = correct_predictions.double() / total_predictions
                print(f'Epoch [{epoch+1}/{self.num_epochs}], Loss: {epoch_loss:.4f}, Accuracy: {epoch_acc:.4f}')
                #saving the best model on the validation
                val_acc = self._check_model()
                if val_acc > best_acc:
                    best_acc = val_acc
                    torch.save(self.model.state_dict(), f"best_{self.selection_criterion}_model.pth")
      print("--"*30)

    def _check_model(self):
        """
        Evaluating the model on the validation set
        """
        self.model.eval()
        running_corrects = 0
        total_predictions = 0.0

        with torch.no_grad():
            for inputs, labels, _ in val_loader:
                inputs = inputs.to(device)
                labels = torch.tensor(labels).to(device)

                outputs = model(inputs)
                # outputs = outputs.logits
                _, preds = torch.max(outputs, 1)

                running_corrects += torch.sum(preds == labels)
                total_predictions += inputs.shape[0]
        val_acc = running_corrects.double() / total_predictions
        return val_acc.item()

    def _evaluate_model(self):
        """
        Evaluate the model on the test set
        :return:
        accuracy: float, accuracy of the model
        """
        self.model.eval()
        running_corrects = 0
        test_images_tensor = torch.stack(test_images)
        label_df_tensor = torch.tensor(test_label_df)
        test_dataset = TensorDataset(test_images_tensor, label_df_tensor)
        batch_size = 32  # Adjust based on your memory and hardware
        test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
        total_predictions = 0.0
        with torch.no_grad():
            for inputs, labels in test_loader:
                inputs = inputs.to(device)
                labels = torch.tensor(labels).to(device)

                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)

                running_corrects += torch.sum(preds == labels)
                total_predictions += inputs.shape[0]
        test_acc = running_corrects.double() / total_predictions
        return test_acc.item()

    def _random_sampling(self):
      selected_indices = np.random.choice(self.available_pool_indices, self.budget_per_iter, replace=False)
      selected_indices = selected_indices.tolist()
      self.train_indices = self.train_indices + selected_indices

      available_pool_set = set(self.available_pool_indices)
      train_set = set(self.train_indices)
      self.available_pool_indices = list(available_pool_set - train_set)



    def _uncertainty_ceal_sampling(self, confidence_threshold):
      """
      The Cost effective active learning strategy
      """
      model = self.model

      X_unlabeled = [train_df.__getitem__(index)[0] for index in self.available_pool_indices]

      pool_images_tensor = torch.stack(X_unlabeled)
      pool_dataset = TensorDataset(pool_images_tensor)

      batch_size = 32
      pool_loader = DataLoader(pool_dataset, batch_size=batch_size, shuffle=False)
      model.eval()
      outputs = []
      with torch.no_grad():
                for inputs in pool_loader:
                    inputs = inputs[0]
                    inputs = inputs.to(device)
                    x = model(inputs)
                    #padding the batch with zero victors to ensure that all the batches have the same size
                    if x.shape[0] != batch_size:
                        padding_tensor = torch.full((batch_size - x.shape[0], 8), 0).to(device)
                        c = batch_size - x.shape[0]
                        x = torch.cat([x, padding_tensor])
                    outputs.append(x)
      probabilities = torch.cat(outputs, dim=0)
      #ignoring the paddings
      probabilities = probabilities[:-c]
      probabilities_cpu = probabilities.cpu().numpy()
      uncertainties = entropy(probabilities_cpu, axis=1)

      selected_indices = np.argsort(uncertainties)[-self.budget_per_iter:]
      temp = np.array(self.available_pool_indices)
      selected_indices = temp[selected_indices]
      # taking the indices of the samples that their uncertainty is less than the threshold
      high_confidence_indices = np.where(uncertainties < confidence_threshold)[0]
      self.high_confidence_labels = np.argmax(probabilities_cpu[high_confidence_indices], axis=1)
      self.high_confidence_indices = temp[high_confidence_indices]


      self.train_indices = self.train_indices + selected_indices.tolist()

      available_pool_set = set(self.available_pool_indices)
      train_set = set(self.train_indices)
      self.available_pool_indices = list(available_pool_set - train_set)

# %%
def generate_plot(accuracy_scores_dict):
    """
    Generate a plot
    """
    for criterion, accuracy_scores in accuracy_scores_dict.items():
        plt.plot(range(1, len(accuracy_scores) + 1), accuracy_scores, label=criterion)
    plt.xlabel('Iterations')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

# %%
available_pool_indices = []
for i in range(len(train_df)):
    image, label, index = train_df[i]
    available_pool_indices.append(index)

test_indices = []
for i in range(len(test_df)):
    image, label, index = test_df[i]
    test_indices.append(index)
test_images = [test_df.__getitem__(index)[0] for index in test_indices]
test_label_df = [class_mapping[test_df.__getitem__(index)[1]] for index in test_indices]

# %%
#According to the initialization that we got using KMeans++ Code of the initialization could be found in the initials file.
train_indices = [1372,
 1277,
 1255,
 1423,
 2925,
 1963,
 2335,
 1923,
 3791,
 1239,
 909,
 134,
 1547,
 3931,
 2467,
 2832,
 1789,
 3022,
 2424,
 780,
 2412,
 3038,
 2158,
 3335,
 1868,
 1771,
 2015,
 1535,
 710,
 3007]
available_pool_set = set(available_pool_indices)
train_set = set(train_indices)
available_pool_indices = list(available_pool_set - train_set)

# %%
# train_indices = []
iterations = 20
budget_per_iter = 60 # 30
num_epoch = 15
selection_criteria = ['uncertainty_ceal'] # uncertainty_ceal_30
accuracy_scores_dict = defaultdict(list)
model = base_model

# %%
for criterion in selection_criteria:
    AL_class = ActiveLearningPipeline(model=model,
                                      test_indices=test_indices,
                                      available_pool_indices=available_pool_indices,
                                      train_indices=train_indices,
                                      selection_criterion=criterion,
                                      iterations=iterations,
                                      budget_per_iter=budget_per_iter,
                                      num_epochs=num_epoch)
    accuracy_scores_dict[criterion] = AL_class.run_pipeline()
generate_plot(accuracy_scores_dict)
# Out:
# --------- Number of Iteration 0 ---------
# /tmp/ipykernel_18491/2766421181.py:86: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   labels = torch.tensor(labels).to(device)
# Epoch [1/15], Loss: 2.0924, Accuracy: 0.1500
# /tmp/ipykernel_18491/2766421181.py:125: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   labels = torch.tensor(labels).to(device)
# Epoch [2/15], Loss: 2.0571, Accuracy: 0.2500
# Epoch [3/15], Loss: 2.0298, Accuracy: 0.3667
# Epoch [4/15], Loss: 1.9901, Accuracy: 0.6000
# Epoch [5/15], Loss: 1.9458, Accuracy: 0.5167
# Epoch [6/15], Loss: 1.8657, Accuracy: 0.6333
# Epoch [7/15], Loss: 1.8144, Accuracy: 0.6333
# Epoch [8/15], Loss: 1.7366, Accuracy: 0.6333
# Epoch [9/15], Loss: 1.6863, Accuracy: 0.7333
# Epoch [10/15], Loss: 1.6195, Accuracy: 0.7833
# Epoch [11/15], Loss: 1.5867, Accuracy: 0.8833
# Epoch [12/15], Loss: 1.5403, Accuracy: 0.8667
# Epoch [13/15], Loss: 1.4900, Accuracy: 0.9000
# Epoch [14/15], Loss: 1.4859, Accuracy: 0.8833
# Epoch [15/15], Loss: 1.4658, Accuracy: 0.8833
# ------------------------------------------------------------
# /tmp/ipykernel_18491/2766421181.py:153: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   labels = torch.tensor(labels).to(device)
# --------- Number of Iteration 1 ---------
# Epoch [1/15], Loss: 1.8278, Accuracy: 0.5333
# Epoch [2/15], Loss: 1.7653, Accuracy: 0.6556
# Epoch [3/15], Loss: 1.7066, Accuracy: 0.7444
# Epoch [4/15], Loss: 1.6719, Accuracy: 0.7778
# Epoch [5/15], Loss: 1.6521, Accuracy: 0.7667
# Epoch [6/15], Loss: 1.6197, Accuracy: 0.8000
# Epoch [7/15], Loss: 1.5745, Accuracy: 0.8000
# Epoch [8/15], Loss: 1.5434, Accuracy: 0.8556
# Epoch [9/15], Loss: 1.5170, Accuracy: 0.8444
# Epoch [10/15], Loss: 1.4967, Accuracy: 0.8444
# Epoch [11/15], Loss: 1.4747, Accuracy: 0.8667
# Epoch [12/15], Loss: 1.4538, Accuracy: 0.8778
# Epoch [13/15], Loss: 1.4613, Accuracy: 0.8778
# Epoch [14/15], Loss: 1.4065, Accuracy: 0.9222
# Epoch [15/15], Loss: 1.4210, Accuracy: 0.8889
# ------------------------------------------------------------
# --------- Number of Iteration 2 ---------
# Epoch [1/15], Loss: 1.7198, Accuracy: 0.6911
# Epoch [2/15], Loss: 1.6752, Accuracy: 0.7398
# Epoch [3/15], Loss: 1.6711, Accuracy: 0.6911
# Epoch [4/15], Loss: 1.6211, Accuracy: 0.7398
# Epoch [5/15], Loss: 1.6171, Accuracy: 0.7642
# Epoch [6/15], Loss: 1.5785, Accuracy: 0.8130
# Epoch [7/15], Loss: 1.5578, Accuracy: 0.7724
# Epoch [8/15], Loss: 1.5337, Accuracy: 0.8455
# Epoch [9/15], Loss: 1.5146, Accuracy: 0.8618
# Epoch [10/15], Loss: 1.5021, Accuracy: 0.8618
# Epoch [11/15], Loss: 1.4946, Accuracy: 0.8537
# Epoch [12/15], Loss: 1.4889, Accuracy: 0.8537
# Epoch [13/15], Loss: 1.4946, Accuracy: 0.8455
# Epoch [14/15], Loss: 1.4379, Accuracy: 0.8943
# Epoch [15/15], Loss: 1.4643, Accuracy: 0.8943
# ------------------------------------------------------------
# --------- Number of Iteration 3 ---------
# Epoch [1/15], Loss: 1.6165, Accuracy: 0.7742
# Epoch [2/15], Loss: 1.6310, Accuracy: 0.7312
# Epoch [3/15], Loss: 1.6166, Accuracy: 0.7634
# Epoch [4/15], Loss: 1.5830, Accuracy: 0.7634
# Epoch [5/15], Loss: 1.5429, Accuracy: 0.8172
# Epoch [6/15], Loss: 1.5415, Accuracy: 0.8118
# Epoch [7/15], Loss: 1.4994, Accuracy: 0.8387
# Epoch [8/15], Loss: 1.4523, Accuracy: 0.8495
# Epoch [9/15], Loss: 1.4466, Accuracy: 0.8925
# Epoch [10/15], Loss: 1.4492, Accuracy: 0.8548
# Epoch [11/15], Loss: 1.4666, Accuracy: 0.8495
# Epoch [12/15], Loss: 1.4171, Accuracy: 0.8763
# Epoch [13/15], Loss: 1.4053, Accuracy: 0.8978
# Epoch [14/15], Loss: 1.4158, Accuracy: 0.9032
# Epoch [15/15], Loss: 1.4033, Accuracy: 0.9086
# ------------------------------------------------------------
# --------- Number of Iteration 4 ---------
# Epoch [1/15], Loss: 1.7118, Accuracy: 0.6766
# Epoch [2/15], Loss: 1.6747, Accuracy: 0.7015
# Epoch [3/15], Loss: 1.6774, Accuracy: 0.6766
# Epoch [4/15], Loss: 1.6362, Accuracy: 0.7164
# Epoch [5/15], Loss: 1.6353, Accuracy: 0.6816
# Epoch [6/15], Loss: 1.6038, Accuracy: 0.7114
# Epoch [7/15], Loss: 1.5882, Accuracy: 0.7164
# Epoch [8/15], Loss: 1.5579, Accuracy: 0.7363
# Epoch [9/15], Loss: 1.5224, Accuracy: 0.7711
# Epoch [10/15], Loss: 1.5057, Accuracy: 0.8358
# Epoch [11/15], Loss: 1.4943, Accuracy: 0.7910
# Epoch [12/15], Loss: 1.4884, Accuracy: 0.8458
# Epoch [13/15], Loss: 1.4763, Accuracy: 0.7910
# Epoch [14/15], Loss: 1.4505, Accuracy: 0.8308
# Epoch [15/15], Loss: 1.4419, Accuracy: 0.8458
# ------------------------------------------------------------
# --------- Number of Iteration 5 ---------
# Epoch [1/15], Loss: 1.5863, Accuracy: 0.6810
# Epoch [2/15], Loss: 1.5640, Accuracy: 0.6762
# Epoch [3/15], Loss: 1.5501, Accuracy: 0.7190
# Epoch [4/15], Loss: 1.5245, Accuracy: 0.7381
# Epoch [5/15], Loss: 1.5174, Accuracy: 0.7667
# Epoch [6/15], Loss: 1.5199, Accuracy: 0.6905
# Epoch [7/15], Loss: 1.4759, Accuracy: 0.7905
# Epoch [8/15], Loss: 1.4914, Accuracy: 0.8000
# Epoch [9/15], Loss: 1.4800, Accuracy: 0.7905
# Epoch [10/15], Loss: 1.4874, Accuracy: 0.7762
# Epoch [11/15], Loss: 1.4503, Accuracy: 0.8429
# Epoch [12/15], Loss: 1.4489, Accuracy: 0.8524
# Epoch [13/15], Loss: 1.4409, Accuracy: 0.8571
# Epoch [14/15], Loss: 1.4293, Accuracy: 0.8476
# Epoch [15/15], Loss: 1.4251, Accuracy: 0.8381
# ------------------------------------------------------------
# --------- Number of Iteration 6 ---------
# Epoch [1/15], Loss: 1.5210, Accuracy: 0.7750
# Epoch [2/15], Loss: 1.5217, Accuracy: 0.7208
# Epoch [3/15], Loss: 1.5107, Accuracy: 0.7667
# Epoch [4/15], Loss: 1.4654, Accuracy: 0.7958
# Epoch [5/15], Loss: 1.4973, Accuracy: 0.8000
# Epoch [6/15], Loss: 1.4694, Accuracy: 0.7583
# Epoch [7/15], Loss: 1.4847, Accuracy: 0.7667
# Epoch [8/15], Loss: 1.4598, Accuracy: 0.8417
# Epoch [9/15], Loss: 1.4416, Accuracy: 0.8083
# Epoch [10/15], Loss: 1.4677, Accuracy: 0.8292
# Epoch [11/15], Loss: 1.4360, Accuracy: 0.8250
# Epoch [12/15], Loss: 1.4424, Accuracy: 0.8375
# Epoch [13/15], Loss: 1.4223, Accuracy: 0.8333
# Epoch [14/15], Loss: 1.4269, Accuracy: 0.8375
# Epoch [15/15], Loss: 1.4226, Accuracy: 0.8417
# ------------------------------------------------------------
# --------- Number of Iteration 7 ---------
# Epoch [1/15], Loss: 1.5775, Accuracy: 0.7444
# Epoch [2/15], Loss: 1.5416, Accuracy: 0.7296
# Epoch [3/15], Loss: 1.5303, Accuracy: 0.7519
# Epoch [4/15], Loss: 1.4879, Accuracy: 0.7815
# Epoch [5/15], Loss: 1.4847, Accuracy: 0.7889
# Epoch [6/15], Loss: 1.4864, Accuracy: 0.7963
# Epoch [7/15], Loss: 1.4717, Accuracy: 0.8037
# Epoch [8/15], Loss: 1.4568, Accuracy: 0.8148
# Epoch [9/15], Loss: 1.4721, Accuracy: 0.8074
# Epoch [10/15], Loss: 1.4518, Accuracy: 0.8037
# Epoch [11/15], Loss: 1.4421, Accuracy: 0.8407
# Epoch [12/15], Loss: 1.4622, Accuracy: 0.8111
# Epoch [13/15], Loss: 1.4623, Accuracy: 0.8074
# Epoch [14/15], Loss: 1.4523, Accuracy: 0.8148
# Epoch [15/15], Loss: 1.4146, Accuracy: 0.8407
# ------------------------------------------------------------
# --------- Number of Iteration 8 ---------
# Epoch [1/15], Loss: 1.4784, Accuracy: 0.8033
# Epoch [2/15], Loss: 1.5020, Accuracy: 0.7433
# Epoch [3/15], Loss: 1.4980, Accuracy: 0.7700
# Epoch [4/15], Loss: 1.4778, Accuracy: 0.8133
# Epoch [5/15], Loss: 1.5077, Accuracy: 0.7867
# Epoch [6/15], Loss: 1.4879, Accuracy: 0.7633
# Epoch [7/15], Loss: 1.4652, Accuracy: 0.8000
# Epoch [8/15], Loss: 1.4335, Accuracy: 0.8267
# Epoch [9/15], Loss: 1.4596, Accuracy: 0.8400
# Epoch [10/15], Loss: 1.4458, Accuracy: 0.8100
# Epoch [11/15], Loss: 1.4589, Accuracy: 0.8400
# Epoch [12/15], Loss: 1.4127, Accuracy: 0.8600
# Epoch [13/15], Loss: 1.4281, Accuracy: 0.8500
# Epoch [14/15], Loss: 1.4472, Accuracy: 0.7767
# Epoch [15/15], Loss: 1.4306, Accuracy: 0.8700
# ------------------------------------------------------------
# --------- Number of Iteration 9 ---------
# Epoch [1/15], Loss: 1.5097, Accuracy: 0.6909
# Epoch [2/15], Loss: 1.4741, Accuracy: 0.7879
# Epoch [3/15], Loss: 1.4441, Accuracy: 0.8061
# Epoch [4/15], Loss: 1.4687, Accuracy: 0.7848
# Epoch [5/15], Loss: 1.4616, Accuracy: 0.8000
# Epoch [6/15], Loss: 1.4375, Accuracy: 0.8121
# Epoch [7/15], Loss: 1.4116, Accuracy: 0.8545
# Epoch [8/15], Loss: 1.4896, Accuracy: 0.7970
# Epoch [9/15], Loss: 1.4410, Accuracy: 0.8182
# Epoch [10/15], Loss: 1.4290, Accuracy: 0.8303
# Epoch [11/15], Loss: 1.4003, Accuracy: 0.8606
# Epoch [12/15], Loss: 1.3952, Accuracy: 0.8576
# Epoch [13/15], Loss: 1.3969, Accuracy: 0.8485
# Epoch [14/15], Loss: 1.4035, Accuracy: 0.8697
# Epoch [15/15], Loss: 1.4319, Accuracy: 0.8061
# ------------------------------------------------------------
# --------- Number of Iteration 10 ---------
# Epoch [1/15], Loss: 1.4768, Accuracy: 0.7583
# Epoch [2/15], Loss: 1.4764, Accuracy: 0.7528
# Epoch [3/15], Loss: 1.4956, Accuracy: 0.7472
# Epoch [4/15], Loss: 1.5038, Accuracy: 0.7611
# Epoch [5/15], Loss: 1.5368, Accuracy: 0.7111
# Epoch [6/15], Loss: 1.4701, Accuracy: 0.7972
# Epoch [7/15], Loss: 1.4493, Accuracy: 0.8083
# Epoch [8/15], Loss: 1.4355, Accuracy: 0.8250
# Epoch [9/15], Loss: 1.4442, Accuracy: 0.8361
# Epoch [10/15], Loss: 1.4487, Accuracy: 0.8278
# Epoch [11/15], Loss: 1.4512, Accuracy: 0.8083
# Epoch [12/15], Loss: 1.4640, Accuracy: 0.7556
# Epoch [13/15], Loss: 1.4231, Accuracy: 0.8472
# Epoch [14/15], Loss: 1.4509, Accuracy: 0.7778
# Epoch [15/15], Loss: 1.4276, Accuracy: 0.8389
# ------------------------------------------------------------
# --------- Number of Iteration 11 ---------
# Epoch [1/15], Loss: 1.4876, Accuracy: 0.7462
# Epoch [2/15], Loss: 1.4994, Accuracy: 0.7744
# Epoch [3/15], Loss: 1.4661, Accuracy: 0.7821
# Epoch [4/15], Loss: 1.4806, Accuracy: 0.7897
# Epoch [5/15], Loss: 1.4701, Accuracy: 0.7846
# Epoch [6/15], Loss: 1.4891, Accuracy: 0.7821
# Epoch [7/15], Loss: 1.5025, Accuracy: 0.7692
# Epoch [8/15], Loss: 1.4746, Accuracy: 0.7436
# Epoch [9/15], Loss: 1.5264, Accuracy: 0.7513
# Epoch [10/15], Loss: 1.4926, Accuracy: 0.7436
# Epoch [11/15], Loss: 1.4654, Accuracy: 0.8000
# Epoch [12/15], Loss: 1.4303, Accuracy: 0.8410
# Epoch [13/15], Loss: 1.3974, Accuracy: 0.8513
# Epoch [14/15], Loss: 1.4258, Accuracy: 0.8410
# Epoch [15/15], Loss: 1.4055, Accuracy: 0.8641
# ------------------------------------------------------------
# --------- Number of Iteration 12 ---------
# Epoch [1/15], Loss: 1.4965, Accuracy: 0.7619
# Epoch [2/15], Loss: 1.4670, Accuracy: 0.7714
# Epoch [3/15], Loss: 1.4724, Accuracy: 0.8190
# Epoch [4/15], Loss: 1.4709, Accuracy: 0.7619
# Epoch [5/15], Loss: 1.4713, Accuracy: 0.7857
# Epoch [6/15], Loss: 1.4641, Accuracy: 0.7905
# Epoch [7/15], Loss: 1.4837, Accuracy: 0.7548
# Epoch [8/15], Loss: 1.5200, Accuracy: 0.6952
# Epoch [9/15], Loss: 1.4824, Accuracy: 0.7857
# Epoch [10/15], Loss: 1.4484, Accuracy: 0.7762
# Epoch [11/15], Loss: 1.5182, Accuracy: 0.7500
# Epoch [12/15], Loss: 1.5080, Accuracy: 0.7167
# Epoch [13/15], Loss: 1.4770, Accuracy: 0.7786
# Epoch [14/15], Loss: 1.4401, Accuracy: 0.8333
# Epoch [15/15], Loss: 1.5658, Accuracy: 0.6690
# ------------------------------------------------------------
# --------- Number of Iteration 13 ---------
# Epoch [1/15], Loss: 1.6141, Accuracy: 0.6822
# Epoch [2/15], Loss: 1.5636, Accuracy: 0.7533
# Epoch [3/15], Loss: 1.6784, Accuracy: 0.6422
# Epoch [4/15], Loss: 1.5229, Accuracy: 0.6600
# Epoch [5/15], Loss: 1.6156, Accuracy: 0.5867
# Epoch [6/15], Loss: 1.5827, Accuracy: 0.6422
# Epoch [7/15], Loss: 1.5694, Accuracy: 0.6311
# Epoch [8/15], Loss: 1.5837, Accuracy: 0.6311
# Epoch [9/15], Loss: 1.5757, Accuracy: 0.6333
# Epoch [10/15], Loss: 1.5650, Accuracy: 0.6089
# Epoch [11/15], Loss: 1.5390, Accuracy: 0.6578
# Epoch [12/15], Loss: 1.5730, Accuracy: 0.6422
# Epoch [13/15], Loss: 1.5349, Accuracy: 0.6333
# Epoch [14/15], Loss: 1.7474, Accuracy: 0.4289
# Epoch [15/15], Loss: 1.7561, Accuracy: 0.4800
# ------------------------------------------------------------
# --------- Number of Iteration 14 ---------
# Epoch [1/15], Loss: 1.5801, Accuracy: 0.6500
# Epoch [2/15], Loss: 1.5190, Accuracy: 0.7396
# Epoch [3/15], Loss: 1.5356, Accuracy: 0.7104
# Epoch [4/15], Loss: 1.4953, Accuracy: 0.7646
# Epoch [5/15], Loss: 1.4781, Accuracy: 0.7812
# Epoch [6/15], Loss: 1.4676, Accuracy: 0.8000
# Epoch [7/15], Loss: 1.4848, Accuracy: 0.8000
# Epoch [8/15], Loss: 1.4910, Accuracy: 0.7646
# Epoch [9/15], Loss: 1.4927, Accuracy: 0.7646
# Epoch [10/15], Loss: 1.4629, Accuracy: 0.8042
# Epoch [11/15], Loss: 1.4458, Accuracy: 0.8229
# Epoch [12/15], Loss: 1.4640, Accuracy: 0.7917
# Epoch [13/15], Loss: 1.4535, Accuracy: 0.8167
# Epoch [14/15], Loss: 1.4511, Accuracy: 0.8208
# Epoch [15/15], Loss: 1.4469, Accuracy: 0.8104
# ------------------------------------------------------------
# --------- Number of Iteration 15 ---------
# Epoch [1/15], Loss: 1.5028, Accuracy: 0.7647
# Epoch [2/15], Loss: 1.5030, Accuracy: 0.7490
# Epoch [3/15], Loss: 1.5019, Accuracy: 0.7569
# Epoch [4/15], Loss: 1.4985, Accuracy: 0.7725
# Epoch [5/15], Loss: 1.4835, Accuracy: 0.7765
# Epoch [6/15], Loss: 1.4727, Accuracy: 0.7843
# Epoch [7/15], Loss: 1.4690, Accuracy: 0.8059
# Epoch [8/15], Loss: 1.4550, Accuracy: 0.8157
# Epoch [9/15], Loss: 1.4803, Accuracy: 0.7843
# Epoch [10/15], Loss: 1.4618, Accuracy: 0.7824
# Epoch [11/15], Loss: 1.4449, Accuracy: 0.8157
# Epoch [12/15], Loss: 1.4543, Accuracy: 0.8196
# Epoch [13/15], Loss: 1.4590, Accuracy: 0.7922
# Epoch [14/15], Loss: 1.4299, Accuracy: 0.8275
# Epoch [15/15], Loss: 1.4517, Accuracy: 0.8020
# ------------------------------------------------------------
# --------- Number of Iteration 16 ---------
# Epoch [1/15], Loss: 1.5004, Accuracy: 0.7593
# Epoch [2/15], Loss: 1.4705, Accuracy: 0.7741
# Epoch [3/15], Loss: 1.4755, Accuracy: 0.7685
# Epoch [4/15], Loss: 1.4747, Accuracy: 0.7944
# Epoch [5/15], Loss: 1.4248, Accuracy: 0.8352
# Epoch [6/15], Loss: 1.4491, Accuracy: 0.8019
# Epoch [7/15], Loss: 1.4720, Accuracy: 0.7741
# Epoch [8/15], Loss: 1.4394, Accuracy: 0.8148
# Epoch [9/15], Loss: 1.4370, Accuracy: 0.8204
# Epoch [10/15], Loss: 1.4464, Accuracy: 0.8000
# Epoch [11/15], Loss: 1.4401, Accuracy: 0.8148
# Epoch [12/15], Loss: 1.4380, Accuracy: 0.8111
# Epoch [13/15], Loss: 1.4176, Accuracy: 0.8556
# Epoch [14/15], Loss: 1.4195, Accuracy: 0.8222
# Epoch [15/15], Loss: 1.4117, Accuracy: 0.8556
# ------------------------------------------------------------
# --------- Number of Iteration 17 ---------
# Epoch [1/15], Loss: 1.4608, Accuracy: 0.8053
# Epoch [2/15], Loss: 1.4588, Accuracy: 0.8018
# Epoch [3/15], Loss: 1.4687, Accuracy: 0.7842
# Epoch [4/15], Loss: 1.4478, Accuracy: 0.8228
# Epoch [5/15], Loss: 1.4492, Accuracy: 0.8053
# Epoch [6/15], Loss: 1.4575, Accuracy: 0.7930
# Epoch [7/15], Loss: 1.4363, Accuracy: 0.8404
# Epoch [8/15], Loss: 1.4406, Accuracy: 0.8263
# Epoch [9/15], Loss: 1.4322, Accuracy: 0.8544
# Epoch [10/15], Loss: 1.4356, Accuracy: 0.8404
# Epoch [11/15], Loss: 1.4446, Accuracy: 0.8175
# Epoch [12/15], Loss: 1.4472, Accuracy: 0.8246
# Epoch [13/15], Loss: 1.4057, Accuracy: 0.8649
# Epoch [14/15], Loss: 1.4185, Accuracy: 0.8561
# Epoch [15/15], Loss: 1.4105, Accuracy: 0.8439
# ------------------------------------------------------------
# --------- Number of Iteration 18 ---------
# Epoch [1/15], Loss: 1.4956, Accuracy: 0.7700
# Epoch [2/15], Loss: 1.4675, Accuracy: 0.7950
# Epoch [3/15], Loss: 1.4737, Accuracy: 0.7950
# Epoch [4/15], Loss: 1.4809, Accuracy: 0.7733
# Epoch [5/15], Loss: 1.4777, Accuracy: 0.7667
# Epoch [6/15], Loss: 1.4663, Accuracy: 0.7883
# Epoch [7/15], Loss: 1.4471, Accuracy: 0.8167
# Epoch [8/15], Loss: 1.4469, Accuracy: 0.8283
# Epoch [9/15], Loss: 1.4295, Accuracy: 0.8417
# Epoch [10/15], Loss: 1.4377, Accuracy: 0.8167
# Epoch [11/15], Loss: 1.4323, Accuracy: 0.8317
# Epoch [12/15], Loss: 1.4281, Accuracy: 0.8283
# Epoch [13/15], Loss: 1.4373, Accuracy: 0.8217
# Epoch [14/15], Loss: 1.4498, Accuracy: 0.8283
# Epoch [15/15], Loss: 1.4422, Accuracy: 0.8167
# ------------------------------------------------------------
# --------- Number of Iteration 19 ---------
# Epoch [1/15], Loss: 1.4635, Accuracy: 0.8048
# Epoch [2/15], Loss: 1.4597, Accuracy: 0.7984
# Epoch [3/15], Loss: 1.4564, Accuracy: 0.8048
# Epoch [4/15], Loss: 1.4526, Accuracy: 0.8270
# Epoch [5/15], Loss: 1.4313, Accuracy: 0.8317
# Epoch [6/15], Loss: 1.4323, Accuracy: 0.8270
# Epoch [7/15], Loss: 1.4547, Accuracy: 0.8016
# Epoch [8/15], Loss: 1.4272, Accuracy: 0.8333
# Epoch [9/15], Loss: 1.4328, Accuracy: 0.8270
# Epoch [10/15], Loss: 1.4360, Accuracy: 0.8333
# Epoch [11/15], Loss: 1.4217, Accuracy: 0.8540
# Epoch [12/15], Loss: 1.4288, Accuracy: 0.8397
# Epoch [13/15], Loss: 1.4140, Accuracy: 0.8540
# Epoch [14/15], Loss: 1.4307, Accuracy: 0.8381
# Epoch [15/15], Loss: 1.4436, Accuracy: 0.8016
# ------------------------------------------------------------

# %%
accuracy_scores_dict
# Out:
# defaultdict(list,
#             {'uncertainty_ceal_30': [0.5376984126984127,
#               0.5085978835978836,
#               0.5218253968253967,
#               0.5138888888888888,
#               0.5132275132275133,
#               0.5277777777777778,
#               0.5509259259259259,
#               0.5998677248677249,
#               0.6329365079365079,
#               0.6243386243386243,
#               0.6441798941798942,
#               0.6455026455026455,
#               0.6223544973544973,
#               0.6521164021164021,
#               0.5925925925925926,
#               0.6369047619047619,
#               0.6474867724867724,
#               0.6203703703703703,
#               0.6018518518518519,
#               0.6216931216931216]})
