# %%
import pandas as pd
import numpy as np
import pickle
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from scipy.stats import entropy
from collections import defaultdict
import argparse
from matplotlib import pyplot as plt

# Load the Data.
train_df = pd.read_csv('train_dataset/metadata.csv')
test_df = pd.read_csv('test_dataset/metadata.csv')
val_df = pd.read_csv('validation_dataset/metadata.csv')

# %%
print(train_df['diagnosis'].value_counts())
# Out:
# diagnosis
# nevus                         1205
# melanoma                      1113
# pigmented benign keratosis    1099
# basal cell carcinoma           514
# squamous cell carcinoma        197
# vascular lesion                142
# actinic keratosis              130
# dermatofibroma                 115
# Name: count, dtype: int64

# %%
class_mapping = {
    "actinic keratosis": 0,
    "basal cell carcinoma": 1,
    "dermatofibroma": 2,
    "melanoma": 3,
    "nevus": 4,
    "pigmented benign keratosis": 5,
    "squamous cell carcinoma": 6,
    "vascular lesion":7
}
class_mapping
# Out:
# {'actinic keratosis': 0,
#  'basal cell carcinoma': 1,
#  'dermatofibroma': 2,
#  'melanoma': 3,
#  'nevus': 4,
#  'pigmented benign keratosis': 5,
#  'squamous cell carcinoma': 6,
#  'vascular lesion': 7}

# %%
from PIL import Image
import os

import torchvision.transforms as transforms

# Define image transformations (resize, convert to tensor)
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

class Dataset():
    def __init__(self, dataframe, transform, train='train'):
        self.dataframe=dataframe
        self.train = train
        self.transform = transform
        self.path_to_image=self._create_path_to_image_dict()
        self.paths=list(self.path_to_image.keys())
        self.labels=list(self.path_to_image.values())

    def _create_path_to_image_dict(self):
      """
      Create a dictionary that maps image paths to their corresponding labels.
      """
      path_to_image={}
      for index,row in self.dataframe.iterrows():
        if self.train == 'train':
          img_path = os.path.join('train_dataset/',row['isic_id']+'.jpg')
        elif self.train == 'test':
          img_path = os.path.join('test_dataset/',row['isic_id']+'.jpg')
        else:
            img_path = os.path.join('validation_dataset/',row['isic_id']+'.jpg')
        label=row['diagnosis']
        path_to_image[img_path]=label
      return path_to_image

    def __len__(self):
        return len(self.paths)

    def __getitem__(self,index):
        """
        Get an image and its corresponding label and index.
        """
        img_path=self.paths[index]
        img_label=self.labels[index]
        image=Image.open(img_path)
        image=self.transform(image)
        if self.train == 'val':
            return image, class_mapping[img_label], index
        return image, img_label, index

# %%
# Create the Datasets.
train_df = Dataset(train_df, transform)
val_df = Dataset(val_df, transform,train='val')
test_df = Dataset(test_df, transform,train='test')

# %%
import torch
import torch.nn as nn
import torchvision.models as models
from torchvision import transforms
from torch.optim import Adam

# Load pre-trained ResNet50 model from torchvision
base_model = models.resnet50(pretrained=True)

# Add a fully connected layer witht the number of classes (for the prediction).
num_classes = 8
base_model.fc = nn.Sequential(
    nn.Flatten(),
    nn.Linear(base_model.fc.in_features, 128),
    nn.ReLU(),
    nn.Linear(128, num_classes),
    nn.Softmax(dim=1)
)

# Freeze all layers except the fully connected ones
for param in base_model.parameters():
    param.requires_grad = False

# Unfreeze the final fully connected layer
for param in base_model.fc.parameters():
    param.requires_grad = True

loss_f = nn.CrossEntropyLoss()
optimizer = Adam(base_model.fc.parameters(), lr=0.0008)

# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
base_model.to(device)
x = 5
# Out:
# /anaconda/envs/py38_default/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /anaconda/envs/py38_default/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
from torch.utils.data import DataLoader, TensorDataset

# Craete validation DataLoader.
batch_size = 4
val_loader = DataLoader(val_df, batch_size=batch_size, shuffle=False)

# %%
class ActiveLearningPipeline:
    def __init__(self, model,
                 available_pool_indices,
                 train_indices,
                 test_indices,
                 selection_criterion,
                 iterations,
                 budget_per_iter,
                 num_epochs):
        self.model = model
        self.iterations = iterations
        self.budget_per_iter = budget_per_iter
        self.available_pool_indices = available_pool_indices
        self.train_indices = train_indices
        self.test_indices = test_indices
        self.selection_criterion = selection_criterion
        if self.selection_criterion == 'random':
          self.train_indices = []
        self.num_epochs = num_epochs
        # self.best_acc = 0

    def run_pipeline(self):
        """
        Run the active learning pipeline
        :return
        accuracy_scores: list, accuracy scores at each iteration
        """
        accuracy_scores = []
        for iteration in range(self.iterations):
            print(f"--------- Number of Iteration {iteration} ---------")
            if self.selection_criterion == 'random':
                self._random_sampling()
            elif self.selection_criterion == 'uncertainty':
                self._uncertainty_sampling()
            else:
              self._custom_sampling(iteration)

            train_images = [train_df.__getitem__(index)[0] for index in self.train_indices]
            label_df = [class_mapping[train_df.__getitem__(index)[1]] for index in self.train_indices]
            self._train_model(train_images, label_df)
            self.model.load_state_dict(torch.load(f"best_{self.selection_criterion}_model.pth"))
            accuracy = self._evaluate_model()
            accuracy_scores.append(accuracy)
        return accuracy_scores

    def calculate_class_weights(self, label_counts, num_classes=8):
        """
        This function is to caculate the inverse probability of each class in the data
        """
        total_samples = sum(label_counts.values())
        class_weights = torch.zeros(num_classes)

        for cls in range(num_classes):
            if cls in label_counts:
                class_weights[cls] = total_samples / (num_classes * label_counts[cls])
            else:
                class_weights[cls] = 1.0  # Handle the case where a class has zero samples in the current epoch

        return class_weights

    def _train_model(self, train_images, label_df):
      label_counts = defaultdict(int)
      for label in label_df:
                label_counts[label] += 1
      class_weights = self.calculate_class_weights(label_counts, 8).to(device)
      # Giving higher weight for the loss of samples that their class is a minority in the data while giving less weight
      # to the loss for classes that are majority
      loss_f = nn.CrossEntropyLoss(weight=class_weights)

      train_images_tensor = torch.stack(train_images)
      label_df_tensor = torch.tensor(label_df)
      train_dataset = TensorDataset(train_images_tensor, label_df_tensor)

      batch_size = 32
      train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
      best_acc = 0
      for epoch in range(self.num_epochs):
                self.model.train()
                running_loss = 0.0
                correct_predictions = 0
                total_predictions = 0
                # Training loop
                for inputs, labels in train_loader:
                    inputs = inputs
                    inputs= inputs.to(device)
                    labels = torch.tensor(labels).to(device)

                    # Zero the parameter gradients
                    optimizer.zero_grad()

                    # Forward pass
                    outputs = self.model(inputs)
                    # outputs = outputs.logits
                    loss = loss_f(outputs, labels)

                    # Backward pass and optimization
                    loss.backward()
                    optimizer.step()

                    running_loss += loss.item()

                    # Calculate accuracy
                    _, preds = torch.max(outputs, 1)
                    correct_predictions += torch.sum(preds == labels)
                    total_predictions += inputs.shape[0]

                # Print loss and accuracy at the end of each epoch
                epoch_loss = running_loss / len(train_loader)
                epoch_acc = correct_predictions.double() / total_predictions
                print(f'Epoch [{epoch+1}/{self.num_epochs}], Loss: {epoch_loss:.4f}, Accuracy: {epoch_acc:.4f}')

                # Saving the best model weights on the validation
                val_acc = self._check_model()
                if val_acc > best_acc:
                    best_acc = val_acc
                    torch.save(self.model.state_dict(), f"best_{self.selection_criterion}_model.pth")
      print("--"*30)

    def _check_model(self):
        """
        This function is used to evaluate the model on the validation set
        """
        self.model.eval()
        running_corrects = 0
        total_predictions = 0.0

        with torch.no_grad():
            for inputs, labels, _ in val_loader:
                inputs = inputs.to(device)
                labels = torch.tensor(labels).to(device)

                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)

                running_corrects += torch.sum(preds == labels)
                total_predictions += inputs.shape[0]
        val_acc = running_corrects.double() / total_predictions
        return val_acc.item()

    def _evaluate_model(self):
        """
        Evaluate the model
        :return:
        accuracy: float, accuracy of the model
        """
        self.model.eval()
        running_corrects = 0
        test_images_tensor = torch.stack(test_images)
        label_df_tensor = torch.tensor(test_label_df)
        test_dataset = TensorDataset(test_images_tensor, label_df_tensor)
        batch_size = 32
        test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
        total_predictions = 0.0
        with torch.no_grad():
            for inputs, labels in test_loader:
                inputs = inputs.to(device)
                labels = torch.tensor(labels).to(device)

                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)

                running_corrects += torch.sum(preds == labels)
                total_predictions += inputs.shape[0]
        test_acc = running_corrects.double() / total_predictions
        return test_acc.item()

    def _random_sampling(self):
      """
      Random sampling strategy
      """
      selected_indices = np.random.choice(self.available_pool_indices, self.budget_per_iter, replace=False)
      selected_indices = selected_indices.tolist()
      self.train_indices = self.train_indices + selected_indices

      available_pool_set = set(self.available_pool_indices)
      train_set = set(self.train_indices)
      self.available_pool_indices = list(available_pool_set - train_set)

    def _uncertainty_sampling(self):
      """
      Uncertainty-Entropy sampling strategy
      """
      model = self.model

      X_unlabeled = [train_df.__getitem__(index)[0] for index in self.available_pool_indices]

      pool_images_tensor = torch.stack(X_unlabeled)
      pool_dataset = TensorDataset(pool_images_tensor)

      batch_size = 32
      pool_loader = DataLoader(pool_dataset, batch_size=batch_size, shuffle=False)
      model.eval()
      outputs = []
      with torch.no_grad():
                for inputs in pool_loader:
                    inputs = inputs[0].to(device)
                    x = model(inputs)
                    if x.shape[0] != batch_size:
                        padding_tensor = torch.full((batch_size - x.shape[0], 8), 0).to(device)
                        c = batch_size - x.shape[0]
                        x = torch.cat([x, padding_tensor])
                    outputs.append(x)
      probabilities = torch.cat(outputs, dim=0)
      probabilities = probabilities[:-c]
      probabilities_cpu = probabilities.cpu().numpy()
      uncertainties = entropy(probabilities_cpu, axis=1)

      selected_indices = np.argsort(uncertainties)[-self.budget_per_iter:]
      temp = np.array(self.available_pool_indices)
      selected_indices = temp[selected_indices]

      self.train_indices = self.train_indices + selected_indices.tolist()

      available_pool_set = set(self.available_pool_indices)
      train_set = set(self.train_indices)
      self.available_pool_indices = list(available_pool_set - train_set)

# %%
def generate_plot(accuracy_scores_dict):
    """
    Generate a plot
    """
    for criterion, accuracy_scores in accuracy_scores_dict.items():
        plt.plot(range(1, len(accuracy_scores) + 1), accuracy_scores, label=criterion)
    plt.xlabel('Iterations')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

# %%
# Loading the images (pool, test datasets).
available_pool_indices = []
for i in range(len(train_df)):
    image, label, index = train_df[i]
    available_pool_indices.append(index)

test_indices = []
for i in range(len(test_df)):
    image, label, index = test_df[i]
    test_indices.append(index)
test_images = [test_df.__getitem__(index)[0] for index in test_indices]
test_label_df = [class_mapping[test_df.__getitem__(index)[1]] for index in test_indices]

# %%
# According to the initialization (using the AutoEncoder) that we got using KMeans++ Code of the initialization could be found in the initials file.
train_indices =  [1380,
 1482,
 1787,
 2612,
 235,
 3743,
 2044,
 2939,
 3667,
 1570,
 779,
 2491,
 4318,
 346,
 2031,
 455,
 4340,
 3895,
 2774,
 4097,
 2119,
 1383,
 822,
 4215,
 2803,
 166,
 137,
 4128,
 1054,
 1118]

 # Hyperparameters Tuning.
iterations = 20
budget_per_iter = 60
num_epoch = 15
selection_criteria = ['uncertainty']
accuracy_scores_dict = defaultdict(list)
model = base_model

# %%
for criterion in selection_criteria:
    AL_class = ActiveLearningPipeline(model=model,
                                      test_indices=test_indices,
                                      available_pool_indices=available_pool_indices,
                                      train_indices=train_indices,
                                      selection_criterion=criterion,
                                      iterations=iterations,
                                      budget_per_iter=budget_per_iter,
                                      num_epochs=num_epoch)
    accuracy_scores_dict[criterion] = AL_class.run_pipeline()
generate_plot(accuracy_scores_dict)
# Out:
# --------- Number of Iteration 0 ---------
# /tmp/ipykernel_79455/2231242555.py:81: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   labels = torch.tensor(labels).to(device)
# Epoch [1/15], Loss: 2.0947, Accuracy: 0.0667
# /tmp/ipykernel_79455/2231242555.py:121: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   labels = torch.tensor(labels).to(device)
# Epoch [2/15], Loss: 2.0429, Accuracy: 0.3111
# Epoch [3/15], Loss: 1.9802, Accuracy: 0.3889
# Epoch [4/15], Loss: 1.9263, Accuracy: 0.2333
# Epoch [5/15], Loss: 1.8733, Accuracy: 0.2556
# Epoch [6/15], Loss: 1.8089, Accuracy: 0.2778
# Epoch [7/15], Loss: 1.7635, Accuracy: 0.3667
# Epoch [8/15], Loss: 1.7167, Accuracy: 0.5444
# Epoch [9/15], Loss: 1.6765, Accuracy: 0.6444
# Epoch [10/15], Loss: 1.6478, Accuracy: 0.7000
# Epoch [11/15], Loss: 1.5832, Accuracy: 0.7556
# Epoch [12/15], Loss: 1.5751, Accuracy: 0.7778
# Epoch [13/15], Loss: 1.5193, Accuracy: 0.8333
# Epoch [14/15], Loss: 1.5385, Accuracy: 0.8222
# Epoch [15/15], Loss: 1.4831, Accuracy: 0.7889
# ------------------------------------------------------------
# /tmp/ipykernel_79455/2231242555.py:149: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   labels = torch.tensor(labels).to(device)
# --------- Number of Iteration 1 ---------
# Epoch [1/15], Loss: 1.8314, Accuracy: 0.5733
# Epoch [2/15], Loss: 1.8094, Accuracy: 0.5133
# Epoch [3/15], Loss: 1.7703, Accuracy: 0.5400
# Epoch [4/15], Loss: 1.7646, Accuracy: 0.6200
# Epoch [5/15], Loss: 1.7170, Accuracy: 0.6333
# Epoch [6/15], Loss: 1.6980, Accuracy: 0.5800
# Epoch [7/15], Loss: 1.6494, Accuracy: 0.6533
# Epoch [8/15], Loss: 1.6116, Accuracy: 0.6733
# Epoch [9/15], Loss: 1.6070, Accuracy: 0.7267
# Epoch [10/15], Loss: 1.6160, Accuracy: 0.6800
# Epoch [11/15], Loss: 1.5763, Accuracy: 0.7067
# Epoch [12/15], Loss: 1.5659, Accuracy: 0.7333
# Epoch [13/15], Loss: 1.5560, Accuracy: 0.7800
# Epoch [14/15], Loss: 1.5209, Accuracy: 0.8067
# Epoch [15/15], Loss: 1.5229, Accuracy: 0.8333
# ------------------------------------------------------------
# --------- Number of Iteration 2 ---------
# Epoch [1/15], Loss: 1.8540, Accuracy: 0.4714
# Epoch [2/15], Loss: 1.8480, Accuracy: 0.5524
# Epoch [3/15], Loss: 1.8059, Accuracy: 0.5619
# Epoch [4/15], Loss: 1.7843, Accuracy: 0.4857
# Epoch [5/15], Loss: 1.7391, Accuracy: 0.5333
# Epoch [6/15], Loss: 1.7292, Accuracy: 0.6333
# Epoch [7/15], Loss: 1.6945, Accuracy: 0.6429
# Epoch [8/15], Loss: 1.6420, Accuracy: 0.6619
# Epoch [9/15], Loss: 1.6107, Accuracy: 0.7095
# Epoch [10/15], Loss: 1.5909, Accuracy: 0.7381
# Epoch [11/15], Loss: 1.6015, Accuracy: 0.7381
# Epoch [12/15], Loss: 1.5753, Accuracy: 0.7857
# Epoch [13/15], Loss: 1.5714, Accuracy: 0.7905
# Epoch [14/15], Loss: 1.5402, Accuracy: 0.8143
# Epoch [15/15], Loss: 1.5290, Accuracy: 0.8143
# ------------------------------------------------------------
# --------- Number of Iteration 3 ---------
# Epoch [1/15], Loss: 1.7654, Accuracy: 0.5852
# Epoch [2/15], Loss: 1.7368, Accuracy: 0.6185
# Epoch [3/15], Loss: 1.7329, Accuracy: 0.6444
# Epoch [4/15], Loss: 1.6917, Accuracy: 0.7148
# Epoch [5/15], Loss: 1.7201, Accuracy: 0.5926
# Epoch [6/15], Loss: 1.6637, Accuracy: 0.6889
# Epoch [7/15], Loss: 1.6425, Accuracy: 0.6926
# Epoch [8/15], Loss: 1.6613, Accuracy: 0.7259
# Epoch [9/15], Loss: 1.6308, Accuracy: 0.7778
# Epoch [10/15], Loss: 1.5974, Accuracy: 0.7630
# Epoch [11/15], Loss: 1.5948, Accuracy: 0.7926
# Epoch [12/15], Loss: 1.5617, Accuracy: 0.8000
# Epoch [13/15], Loss: 1.5624, Accuracy: 0.7963
# Epoch [14/15], Loss: 1.5876, Accuracy: 0.7778
# Epoch [15/15], Loss: 1.5570, Accuracy: 0.7593
# ------------------------------------------------------------
# --------- Number of Iteration 4 ---------
# Epoch [1/15], Loss: 1.6690, Accuracy: 0.7061
# Epoch [2/15], Loss: 1.6772, Accuracy: 0.6697
# Epoch [3/15], Loss: 1.6591, Accuracy: 0.6970
# Epoch [4/15], Loss: 1.6713, Accuracy: 0.6970
# Epoch [5/15], Loss: 1.6753, Accuracy: 0.6939
# Epoch [6/15], Loss: 1.6253, Accuracy: 0.7121
# Epoch [7/15], Loss: 1.5851, Accuracy: 0.8000
# Epoch [8/15], Loss: 1.5838, Accuracy: 0.7394
# Epoch [9/15], Loss: 1.6039, Accuracy: 0.7121
# Epoch [10/15], Loss: 1.5778, Accuracy: 0.8182
# Epoch [11/15], Loss: 1.5945, Accuracy: 0.7455
# Epoch [12/15], Loss: 1.5427, Accuracy: 0.8152
# Epoch [13/15], Loss: 1.5524, Accuracy: 0.8121
# Epoch [14/15], Loss: 1.5171, Accuracy: 0.8273
# Epoch [15/15], Loss: 1.5123, Accuracy: 0.8455
# ------------------------------------------------------------
# --------- Number of Iteration 5 ---------
# Epoch [1/15], Loss: 1.7109, Accuracy: 0.6538
# Epoch [2/15], Loss: 1.7047, Accuracy: 0.6487
# Epoch [3/15], Loss: 1.7248, Accuracy: 0.6385
# Epoch [4/15], Loss: 1.6602, Accuracy: 0.6487
# Epoch [5/15], Loss: 1.6557, Accuracy: 0.6359
# Epoch [6/15], Loss: 1.6391, Accuracy: 0.7128
# Epoch [7/15], Loss: 1.6487, Accuracy: 0.6026
# Epoch [8/15], Loss: 1.6160, Accuracy: 0.7154
# Epoch [9/15], Loss: 1.6100, Accuracy: 0.7256
# Epoch [10/15], Loss: 1.6015, Accuracy: 0.7282
# Epoch [11/15], Loss: 1.6102, Accuracy: 0.6564
# Epoch [12/15], Loss: 1.5812, Accuracy: 0.7538
# Epoch [13/15], Loss: 1.6082, Accuracy: 0.7282
# Epoch [14/15], Loss: 1.5558, Accuracy: 0.7692
# Epoch [15/15], Loss: 1.5652, Accuracy: 0.7436
# ------------------------------------------------------------
# --------- Number of Iteration 6 ---------
# Epoch [1/15], Loss: 1.6556, Accuracy: 0.6911
# Epoch [2/15], Loss: 1.6831, Accuracy: 0.6289
# Epoch [3/15], Loss: 1.6888, Accuracy: 0.6622
# Epoch [4/15], Loss: 1.7129, Accuracy: 0.5333
# Epoch [5/15], Loss: 1.6119, Accuracy: 0.6889
# Epoch [6/15], Loss: 1.6905, Accuracy: 0.5778
# Epoch [7/15], Loss: 1.6236, Accuracy: 0.7067
# Epoch [8/15], Loss: 1.6989, Accuracy: 0.6022
# Epoch [9/15], Loss: 1.6160, Accuracy: 0.6933
# Epoch [10/15], Loss: 1.6213, Accuracy: 0.6667
# Epoch [11/15], Loss: 1.6117, Accuracy: 0.7178
# Epoch [12/15], Loss: 1.5762, Accuracy: 0.7222
# Epoch [13/15], Loss: 1.6678, Accuracy: 0.6289
# Epoch [14/15], Loss: 1.7216, Accuracy: 0.4622
# Epoch [15/15], Loss: 1.6600, Accuracy: 0.5044
# ------------------------------------------------------------
# --------- Number of Iteration 7 ---------
# Epoch [1/15], Loss: 1.6335, Accuracy: 0.6725
# Epoch [2/15], Loss: 1.6328, Accuracy: 0.6902
# Epoch [3/15], Loss: 1.6043, Accuracy: 0.7059
# Epoch [4/15], Loss: 1.6170, Accuracy: 0.6922
# Epoch [5/15], Loss: 1.6013, Accuracy: 0.7216
# Epoch [6/15], Loss: 1.6236, Accuracy: 0.6667
# Epoch [7/15], Loss: 1.5957, Accuracy: 0.7176
# Epoch [8/15], Loss: 1.5858, Accuracy: 0.7314
# Epoch [9/15], Loss: 1.5758, Accuracy: 0.7608
# Epoch [10/15], Loss: 1.5632, Accuracy: 0.7510
# Epoch [11/15], Loss: 1.5716, Accuracy: 0.7490
# Epoch [12/15], Loss: 1.5805, Accuracy: 0.7333
# Epoch [13/15], Loss: 1.5756, Accuracy: 0.7529
# Epoch [14/15], Loss: 1.5671, Accuracy: 0.7569
# Epoch [15/15], Loss: 1.5582, Accuracy: 0.7765
# ------------------------------------------------------------
# --------- Number of Iteration 8 ---------
# Epoch [1/15], Loss: 1.6004, Accuracy: 0.7070
# Epoch [2/15], Loss: 1.6138, Accuracy: 0.6912
# Epoch [3/15], Loss: 1.6027, Accuracy: 0.7316
# Epoch [4/15], Loss: 1.5986, Accuracy: 0.7228
# Epoch [5/15], Loss: 1.5902, Accuracy: 0.7246
# Epoch [6/15], Loss: 1.5919, Accuracy: 0.7088
# Epoch [7/15], Loss: 1.5743, Accuracy: 0.7368
# Epoch [8/15], Loss: 1.5688, Accuracy: 0.7439
# Epoch [9/15], Loss: 1.5548, Accuracy: 0.7596
# Epoch [10/15], Loss: 1.5524, Accuracy: 0.7789
# Epoch [11/15], Loss: 1.5490, Accuracy: 0.7825
# Epoch [12/15], Loss: 1.5670, Accuracy: 0.7404
# Epoch [13/15], Loss: 1.5823, Accuracy: 0.7193
# Epoch [14/15], Loss: 1.5524, Accuracy: 0.7895
# Epoch [15/15], Loss: 1.5498, Accuracy: 0.7737
# ------------------------------------------------------------
# --------- Number of Iteration 9 ---------
# Epoch [1/15], Loss: 1.6540, Accuracy: 0.6683
# Epoch [2/15], Loss: 1.6281, Accuracy: 0.6698
# Epoch [3/15], Loss: 1.6465, Accuracy: 0.6667
# Epoch [4/15], Loss: 1.6143, Accuracy: 0.6937
# Epoch [5/15], Loss: 1.6125, Accuracy: 0.6778
# Epoch [6/15], Loss: 1.6233, Accuracy: 0.6825
# Epoch [7/15], Loss: 1.6153, Accuracy: 0.6794
# Epoch [8/15], Loss: 1.5657, Accuracy: 0.7444
# Epoch [9/15], Loss: 1.5743, Accuracy: 0.7333
# Epoch [10/15], Loss: 1.5922, Accuracy: 0.7000
# Epoch [11/15], Loss: 1.5822, Accuracy: 0.7460
# Epoch [12/15], Loss: 1.5758, Accuracy: 0.7444
# Epoch [13/15], Loss: 1.5694, Accuracy: 0.7333
# Epoch [14/15], Loss: 1.5703, Accuracy: 0.7175
# Epoch [15/15], Loss: 1.5933, Accuracy: 0.6857
# ------------------------------------------------------------
# --------- Number of Iteration 10 ---------
# Epoch [1/15], Loss: 1.6458, Accuracy: 0.6203
# Epoch [2/15], Loss: 1.6113, Accuracy: 0.6826
# Epoch [3/15], Loss: 1.6188, Accuracy: 0.6754
# Epoch [4/15], Loss: 1.6098, Accuracy: 0.6783
# Epoch [5/15], Loss: 1.6376, Accuracy: 0.6174
# Epoch [6/15], Loss: 1.5877, Accuracy: 0.7261
# Epoch [7/15], Loss: 1.5906, Accuracy: 0.7043
# Epoch [8/15], Loss: 1.5839, Accuracy: 0.7159
# Epoch [9/15], Loss: 1.5875, Accuracy: 0.7246
# Epoch [10/15], Loss: 1.5851, Accuracy: 0.7116
# Epoch [11/15], Loss: 1.5787, Accuracy: 0.7159
# Epoch [12/15], Loss: 1.5863, Accuracy: 0.6986
# Epoch [13/15], Loss: 1.5781, Accuracy: 0.7116
# Epoch [14/15], Loss: 1.5856, Accuracy: 0.6609
# Epoch [15/15], Loss: 1.5330, Accuracy: 0.7420
# ------------------------------------------------------------
# --------- Number of Iteration 11 ---------
# Epoch [1/15], Loss: 1.5700, Accuracy: 0.6947
# Epoch [2/15], Loss: 1.5605, Accuracy: 0.7040
# Epoch [3/15], Loss: 1.5232, Accuracy: 0.7347
# Epoch [4/15], Loss: 1.5592, Accuracy: 0.6373
# Epoch [5/15], Loss: 1.5391, Accuracy: 0.7053
# Epoch [6/15], Loss: 1.5389, Accuracy: 0.7200
# Epoch [7/15], Loss: 1.5013, Accuracy: 0.7467
# Epoch [8/15], Loss: 1.4928, Accuracy: 0.7613
# Epoch [9/15], Loss: 1.5001, Accuracy: 0.7600
# Epoch [10/15], Loss: 1.4816, Accuracy: 0.7493
# Epoch [11/15], Loss: 1.5092, Accuracy: 0.7200
# Epoch [12/15], Loss: 1.4897, Accuracy: 0.7600
# Epoch [13/15], Loss: 1.4745, Accuracy: 0.7747
# Epoch [14/15], Loss: 1.4734, Accuracy: 0.7587
# Epoch [15/15], Loss: 1.4862, Accuracy: 0.7493
# ------------------------------------------------------------
# --------- Number of Iteration 12 ---------
# Epoch [1/15], Loss: 1.5594, Accuracy: 0.6790
# Epoch [2/15], Loss: 1.5476, Accuracy: 0.7025
# Epoch [3/15], Loss: 1.5478, Accuracy: 0.6889
# Epoch [4/15], Loss: 1.5424, Accuracy: 0.6889
# Epoch [5/15], Loss: 1.5489, Accuracy: 0.6778
# Epoch [6/15], Loss: 1.5452, Accuracy: 0.7099
# Epoch [7/15], Loss: 1.5208, Accuracy: 0.7049
# Epoch [8/15], Loss: 1.5146, Accuracy: 0.7469
# Epoch [9/15], Loss: 1.5145, Accuracy: 0.7173
# Epoch [10/15], Loss: 1.5050, Accuracy: 0.7444
# Epoch [11/15], Loss: 1.5034, Accuracy: 0.7556
# Epoch [12/15], Loss: 1.4772, Accuracy: 0.7691
# Epoch [13/15], Loss: 1.4936, Accuracy: 0.7481
# Epoch [14/15], Loss: 1.5047, Accuracy: 0.7506
# Epoch [15/15], Loss: 1.5242, Accuracy: 0.6951
# ------------------------------------------------------------
# --------- Number of Iteration 13 ---------
# Epoch [1/15], Loss: 1.5771, Accuracy: 0.6494
# Epoch [2/15], Loss: 1.5505, Accuracy: 0.6943
# Epoch [3/15], Loss: 1.5793, Accuracy: 0.6586
# Epoch [4/15], Loss: 1.5328, Accuracy: 0.6931
# Epoch [5/15], Loss: 1.5385, Accuracy: 0.6759
# Epoch [6/15], Loss: 1.5172, Accuracy: 0.7448
# Epoch [7/15], Loss: 1.5482, Accuracy: 0.7057
# Epoch [8/15], Loss: 1.5082, Accuracy: 0.7299
# Epoch [9/15], Loss: 1.5038, Accuracy: 0.7333
# Epoch [10/15], Loss: 1.5276, Accuracy: 0.6747
# Epoch [11/15], Loss: 1.5173, Accuracy: 0.7149
# Epoch [12/15], Loss: 1.4995, Accuracy: 0.7253
# Epoch [13/15], Loss: 1.5005, Accuracy: 0.7368
# Epoch [14/15], Loss: 1.5345, Accuracy: 0.7034
# Epoch [15/15], Loss: 1.5526, Accuracy: 0.6563
# ------------------------------------------------------------
# --------- Number of Iteration 14 ---------
# Epoch [1/15], Loss: 1.5232, Accuracy: 0.7237
# Epoch [2/15], Loss: 1.5506, Accuracy: 0.6570
# Epoch [3/15], Loss: 1.5226, Accuracy: 0.7140
# Epoch [4/15], Loss: 1.4996, Accuracy: 0.7398
# Epoch [5/15], Loss: 1.5362, Accuracy: 0.7022
# Epoch [6/15], Loss: 1.5381, Accuracy: 0.6806
# Epoch [7/15], Loss: 1.5008, Accuracy: 0.7581
# Epoch [8/15], Loss: 1.4881, Accuracy: 0.7634
# Epoch [9/15], Loss: 1.5344, Accuracy: 0.6860
# Epoch [10/15], Loss: 1.4987, Accuracy: 0.7237
# Epoch [11/15], Loss: 1.5153, Accuracy: 0.7430
# Epoch [12/15], Loss: 1.5042, Accuracy: 0.7484
# Epoch [13/15], Loss: 1.5033, Accuracy: 0.7538
# Epoch [14/15], Loss: 1.4783, Accuracy: 0.7699
# Epoch [15/15], Loss: 1.4899, Accuracy: 0.7656
# ------------------------------------------------------------
# --------- Number of Iteration 15 ---------
# Epoch [1/15], Loss: 1.5364, Accuracy: 0.6778
# Epoch [2/15], Loss: 1.5041, Accuracy: 0.7141
# Epoch [3/15], Loss: 1.5119, Accuracy: 0.7152
# Epoch [4/15], Loss: 1.5067, Accuracy: 0.7253
# Epoch [5/15], Loss: 1.5015, Accuracy: 0.7232
# Epoch [6/15], Loss: 1.5085, Accuracy: 0.6990
# Epoch [7/15], Loss: 1.4895, Accuracy: 0.7434
# Epoch [8/15], Loss: 1.4980, Accuracy: 0.7333
# Epoch [9/15], Loss: 1.4963, Accuracy: 0.7343
# Epoch [10/15], Loss: 1.4832, Accuracy: 0.7596
# Epoch [11/15], Loss: 1.4986, Accuracy: 0.7182
# Epoch [12/15], Loss: 1.4807, Accuracy: 0.7525
# Epoch [13/15], Loss: 1.4835, Accuracy: 0.7444
# Epoch [14/15], Loss: 1.4650, Accuracy: 0.7717
# Epoch [15/15], Loss: 1.4662, Accuracy: 0.7586
# ------------------------------------------------------------
# --------- Number of Iteration 16 ---------
# Epoch [1/15], Loss: 1.5243, Accuracy: 0.6952
# Epoch [2/15], Loss: 1.5029, Accuracy: 0.6981
# Epoch [3/15], Loss: 1.4911, Accuracy: 0.7381
# Epoch [4/15], Loss: 1.5000, Accuracy: 0.7200
# Epoch [5/15], Loss: 1.4913, Accuracy: 0.7448
# Epoch [6/15], Loss: 1.4894, Accuracy: 0.7438
# Epoch [7/15], Loss: 1.4909, Accuracy: 0.7381
# Epoch [8/15], Loss: 1.4983, Accuracy: 0.7267
# Epoch [9/15], Loss: 1.4785, Accuracy: 0.7410
# Epoch [10/15], Loss: 1.4725, Accuracy: 0.7571
# Epoch [11/15], Loss: 1.4715, Accuracy: 0.7686
# Epoch [12/15], Loss: 1.4737, Accuracy: 0.7524
# Epoch [13/15], Loss: 1.4719, Accuracy: 0.7514
# Epoch [14/15], Loss: 1.4714, Accuracy: 0.7676
# Epoch [15/15], Loss: 1.4734, Accuracy: 0.7581
# ------------------------------------------------------------
# --------- Number of Iteration 17 ---------
# Epoch [1/15], Loss: 1.5326, Accuracy: 0.6910
# Epoch [2/15], Loss: 1.5171, Accuracy: 0.6973
# Epoch [3/15], Loss: 1.5050, Accuracy: 0.7270
# Epoch [4/15], Loss: 1.5133, Accuracy: 0.7018
# Epoch [5/15], Loss: 1.5027, Accuracy: 0.7288
# Epoch [6/15], Loss: 1.4948, Accuracy: 0.7279
# Epoch [7/15], Loss: 1.4943, Accuracy: 0.7315
# Epoch [8/15], Loss: 1.5237, Accuracy: 0.7000
# Epoch [9/15], Loss: 1.4962, Accuracy: 0.7243
# Epoch [10/15], Loss: 1.4706, Accuracy: 0.7613
# Epoch [11/15], Loss: 1.4714, Accuracy: 0.7577
# Epoch [12/15], Loss: 1.4781, Accuracy: 0.7550
# Epoch [13/15], Loss: 1.4717, Accuracy: 0.7468
# Epoch [14/15], Loss: 1.4671, Accuracy: 0.7685
# Epoch [15/15], Loss: 1.4747, Accuracy: 0.7414
# ------------------------------------------------------------
# --------- Number of Iteration 18 ---------
# Epoch [1/15], Loss: 1.5172, Accuracy: 0.7128
# Epoch [2/15], Loss: 1.5182, Accuracy: 0.7026
# Epoch [3/15], Loss: 1.4961, Accuracy: 0.7444
# Epoch [4/15], Loss: 1.5201, Accuracy: 0.7051
# Epoch [5/15], Loss: 1.5473, Accuracy: 0.6632
# Epoch [6/15], Loss: 1.5140, Accuracy: 0.7051
# Epoch [7/15], Loss: 1.4696, Accuracy: 0.7650
# Epoch [8/15], Loss: 1.4973, Accuracy: 0.7342
# Epoch [9/15], Loss: 1.4965, Accuracy: 0.7162
# Epoch [10/15], Loss: 1.4864, Accuracy: 0.7444
# Epoch [11/15], Loss: 1.4786, Accuracy: 0.7410
# Epoch [12/15], Loss: 1.4902, Accuracy: 0.7393
# Epoch [13/15], Loss: 1.4883, Accuracy: 0.7376
# Epoch [14/15], Loss: 1.5066, Accuracy: 0.7282
# Epoch [15/15], Loss: 1.4675, Accuracy: 0.7513
# ------------------------------------------------------------
# --------- Number of Iteration 19 ---------
# Epoch [1/15], Loss: 1.4968, Accuracy: 0.7496
# Epoch [2/15], Loss: 1.4934, Accuracy: 0.7341
# Epoch [3/15], Loss: 1.5064, Accuracy: 0.7415
# Epoch [4/15], Loss: 1.5475, Accuracy: 0.6626
# Epoch [5/15], Loss: 1.5203, Accuracy: 0.7187
# Epoch [6/15], Loss: 1.4856, Accuracy: 0.7488
# Epoch [7/15], Loss: 1.5059, Accuracy: 0.7098
# Epoch [8/15], Loss: 1.4738, Accuracy: 0.7602
# Epoch [9/15], Loss: 1.4751, Accuracy: 0.7504
# Epoch [10/15], Loss: 1.4859, Accuracy: 0.7423
# Epoch [11/15], Loss: 1.4570, Accuracy: 0.7919
# Epoch [12/15], Loss: 1.4713, Accuracy: 0.7707
# Epoch [13/15], Loss: 1.4762, Accuracy: 0.7423
# Epoch [14/15], Loss: 1.4655, Accuracy: 0.7683
# Epoch [15/15], Loss: 1.4564, Accuracy: 0.7870
# ------------------------------------------------------------

# %%
accuracy_scores_dict
# Out:
# defaultdict(list,
#             {'uncertainty': [0.5740740740740741,
#               0.5383597883597884,
#               0.611111111111111,
#               0.6428571428571428,
#               0.6693121693121693,
#               0.6792328042328042,
#               0.6957671957671957,
#               0.673941798941799,
#               0.6415343915343915,
#               0.6461640211640212,
#               0.6779100529100529,
#               0.658068783068783,
#               0.6785714285714285,
#               0.6481481481481481,
#               0.6567460317460317,
#               0.6812169312169312,
#               0.6646825396825397,
#               0.6904761904761905,
#               0.6891534391534391,
#               0.6878306878306878]})
