# %%
import pandas as pd
import numpy as np
import pickle
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from scipy.stats import entropy
from collections import defaultdict
import argparse
from matplotlib import pyplot as plt

# Load the Data.
train_df = pd.read_csv('train_dataset/metadata.csv')
test_df = pd.read_csv('test_dataset/metadata.csv')
val_df = pd.read_csv('validation_dataset/metadata.csv')

# %%
print(train_df['diagnosis'].value_counts())
# Out:
# diagnosis
# nevus                         1205
# melanoma                      1113
# pigmented benign keratosis    1099
# basal cell carcinoma           514
# squamous cell carcinoma        197
# vascular lesion                142
# actinic keratosis              130
# dermatofibroma                 115
# Name: count, dtype: int64

# %%
class_mapping = {
    "actinic keratosis": 0,
    "basal cell carcinoma": 1,
    "dermatofibroma": 2,
    "melanoma": 3,
    "nevus": 4,
    "pigmented benign keratosis": 5,
    "squamous cell carcinoma": 6,
    "vascular lesion":7
}
class_mapping
# Out:
# {'actinic keratosis': 0,
#  'basal cell carcinoma': 1,
#  'dermatofibroma': 2,
#  'melanoma': 3,
#  'nevus': 4,
#  'pigmented benign keratosis': 5,
#  'squamous cell carcinoma': 6,
#  'vascular lesion': 7}

# %%
from PIL import Image
import os

import torchvision.transforms as transforms

# Define image transformations (resize, convert to tensor)
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

class Dataset():
    def __init__(self, dataframe, transform, train='train'):
        self.dataframe=dataframe
        self.train = train
        self.transform = transform
        self.path_to_image=self._create_path_to_image_dict()
        self.paths=list(self.path_to_image.keys())
        self.labels=list(self.path_to_image.values())

    def _create_path_to_image_dict(self):
      """
      Create a dictionary that maps image paths to their corresponding labels.
      """
      path_to_image={}
      for index,row in self.dataframe.iterrows():
        if self.train == 'train':
          img_path = os.path.join('train_dataset/',row['isic_id']+'.jpg')
        elif self.train == 'test':
          img_path = os.path.join('test_dataset/',row['isic_id']+'.jpg')
        else:
            img_path = os.path.join('validation_dataset/',row['isic_id']+'.jpg')
        label=row['diagnosis']
        path_to_image[img_path]=label
      return path_to_image

    def __len__(self):
        return len(self.paths)

    def __getitem__(self,index):
        """
        Get an image and its corresponding label and index.
        """
        img_path=self.paths[index]
        img_label=self.labels[index]
        image=Image.open(img_path)
        image=self.transform(image)
        if self.train == 'val':
            return image, class_mapping[img_label], index
        return image, img_label, index

# %%
# Create the Datasets.
train_df = Dataset(train_df, transform)
val_df = Dataset(val_df, transform,train='val')
test_df = Dataset(test_df, transform,train='test')

# %%
import torch
import torch.nn as nn
import torchvision.models as models
from torchvision import transforms
from torch.optim import Adam

# Load pre-trained ResNet50 model from torchvision
base_model = models.resnet50(pretrained=True)

# Add a fully connected layer witht the number of classes (for the prediction).
num_classes = 8
base_model.fc = nn.Sequential(
    nn.Flatten(),
    nn.Linear(base_model.fc.in_features, 128),
    nn.ReLU(),
    nn.Linear(128, num_classes),
    nn.Softmax(dim=1)
)
# Freeze all layers except the fully connected ones
for param in base_model.parameters():
    param.requires_grad = False

# Unfreeze the final fully connected layer
for param in base_model.fc.parameters():
    param.requires_grad = True

loss_f = nn.CrossEntropyLoss()
optimizer = Adam(base_model.fc.parameters(), lr=0.0008)

# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
base_model.to(device)
x = 5
# Out:
# /anaconda/envs/py38_default/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /anaconda/envs/py38_default/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
from torch.utils.data import DataLoader, TensorDataset

# Craete validation DataLoader.
batch_size = 4
val_loader = DataLoader(val_df, batch_size=batch_size, shuffle=False)

# %%
class ActiveLearningPipeline:
    def __init__(self, model,
                 available_pool_indices,
                 train_indices,
                 test_indices,
                 selection_criterion,
                 iterations,
                 budget_per_iter,
                 num_epochs):
        self.model = model
        self.iterations = iterations
        self.budget_per_iter = budget_per_iter
        self.available_pool_indices = available_pool_indices
        self.train_indices = train_indices
        self.test_indices = test_indices
        self.selection_criterion = selection_criterion
        if self.selection_criterion == 'random':
          self.train_indices = []
        self.num_epochs = num_epochs
        # self.best_acc = 0

    def run_pipeline(self):
        """
        Run the active learning pipeline
        :return
        accuracy_scores: list, accuracy scores at each iteration
        """
        accuracy_scores = []
        for iteration in range(self.iterations):
            print(f"--------- Number of Iteration {iteration} ---------")
            if self.selection_criterion == 'random':
                self._random_sampling()
            elif self.selection_criterion == 'uncertainty':
                self._uncertainty_sampling()
            else:
              self._custom_sampling(iteration)

            train_images = [train_df.__getitem__(index)[0] for index in self.train_indices]
            label_df = [class_mapping[train_df.__getitem__(index)[1]] for index in self.train_indices]
            self._train_model(train_images, label_df)
            self.model.load_state_dict(torch.load(f"best_{self.selection_criterion}_model.pth"))
            accuracy = self._evaluate_model()
            accuracy_scores.append(accuracy)
        return accuracy_scores

    def calculate_class_weights(self, label_counts, num_classes=8):
        """
        This function is to caculate the inverse probability of each class in the data
        """
        total_samples = sum(label_counts.values())
        class_weights = torch.zeros(num_classes)

        for cls in range(num_classes):
            if cls in label_counts:
                class_weights[cls] = total_samples / (num_classes * label_counts[cls])
            else:
                class_weights[cls] = 1.0  # Handle the case where a class has zero samples in the current epoch

        return class_weights

    def _train_model(self, train_images, label_df):
      label_counts = defaultdict(int)
      for label in label_df:
                label_counts[label] += 1
      class_weights = self.calculate_class_weights(label_counts, 8).to(device)

      # Giving higher weight for the loss of samples that their class is a minority in the data while giving less weight
      # to the loss for classes that are majority
      loss_f = nn.CrossEntropyLoss(weight=class_weights)

      train_images_tensor = torch.stack(train_images)
      label_df_tensor = torch.tensor(label_df)
      train_dataset = TensorDataset(train_images_tensor, label_df_tensor)

      batch_size = 32
      train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
      best_acc = 0
      for epoch in range(self.num_epochs):
                self.model.train()
                running_loss = 0.0
                correct_predictions = 0
                total_predictions = 0
                # Training loop
                for inputs, labels in train_loader:
                    inputs = inputs
                    inputs= inputs.to(device)
                    labels = torch.tensor(labels).to(device)

                    # Zero the parameter gradients
                    optimizer.zero_grad()

                    # Forward pass
                    outputs = self.model(inputs)
                    # outputs = outputs.logits
                    loss = loss_f(outputs, labels)

                    # Backward pass and optimization
                    loss.backward()
                    optimizer.step()

                    running_loss += loss.item()

                    # Calculate accuracy
                    _, preds = torch.max(outputs, 1)
                    correct_predictions += torch.sum(preds == labels)
                    total_predictions += inputs.shape[0]

                # Print loss and accuracy at the end of each epoch
                epoch_loss = running_loss / len(train_loader)
                epoch_acc = correct_predictions.double() / total_predictions
                print(f'Epoch [{epoch+1}/{self.num_epochs}], Loss: {epoch_loss:.4f}, Accuracy: {epoch_acc:.4f}')

                # Saving the best model weights on the validation
                val_acc = self._check_model()
                if val_acc > best_acc:
                    best_acc = val_acc
                    torch.save(self.model.state_dict(), f"best_{self.selection_criterion}_model.pth")
      print("--"*30)

    def _check_model(self):
        """
        This function is used to evaluate the model on the validation set
        """
        self.model.eval()
        running_corrects = 0
        total_predictions = 0.0

        with torch.no_grad():
            for inputs, labels, _ in val_loader:
                inputs = inputs.to(device)
                labels = torch.tensor(labels).to(device)

                outputs = model(inputs)
                # outputs = outputs.logits
                _, preds = torch.max(outputs, 1)

                running_corrects += torch.sum(preds == labels)
                total_predictions += inputs.shape[0]
        val_acc = running_corrects.double() / total_predictions
        return val_acc.item()

    def _evaluate_model(self):
        """
        Evaluate the model
        :return:
        accuracy: float, accuracy of the model
        """
        self.model.eval()
        running_corrects = 0
        test_images_tensor = torch.stack(test_images)
        label_df_tensor = torch.tensor(test_label_df)
        test_dataset = TensorDataset(test_images_tensor, label_df_tensor)
        batch_size = 32  # Adjust based on your memory and hardware
        test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
        total_predictions = 0.0
        with torch.no_grad():
            for inputs, labels in test_loader:
                inputs = inputs.to(device)
                labels = torch.tensor(labels).to(device)

                outputs = model(inputs)
                # outputs = outputs.logits
                _, preds = torch.max(outputs, 1)

                running_corrects += torch.sum(preds == labels)
                total_predictions += inputs.shape[0]
        test_acc = running_corrects.double() / total_predictions
        return test_acc.item()

    def _random_sampling(self):
      """
      Random sampling strategy
      """
      selected_indices = np.random.choice(self.available_pool_indices, self.budget_per_iter, replace=False)
      selected_indices = selected_indices.tolist()
      self.train_indices = self.train_indices + selected_indices

      available_pool_set = set(self.available_pool_indices)
      train_set = set(self.train_indices)
      self.available_pool_indices = list(available_pool_set - train_set)

# %%
def generate_plot(accuracy_scores_dict):
    """
    Generate a plot
    """
    for criterion, accuracy_scores in accuracy_scores_dict.items():
        plt.plot(range(1, len(accuracy_scores) + 1), accuracy_scores, label=criterion)
    plt.xlabel('Iterations')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

# %%
# Loading the images (pool, test datasets).
available_pool_indices = []
for i in range(len(train_df)):
    image, label, index = train_df[i]
    available_pool_indices.append(index)

test_indices = []
for i in range(len(test_df)):
    image, label, index = test_df[i]
    test_indices.append(index)
test_images = [test_df.__getitem__(index)[0] for index in test_indices]
test_label_df = [class_mapping[test_df.__getitem__(index)[1]] for index in test_indices]

# %%
# Hyperparameters Tuning.
train_indices =  []
iterations = 20
budget_per_iter = 60
num_epoch = 15
selection_criteria = ['random']
accuracy_scores_dict = defaultdict(list)
model = base_model

# %%
for criterion in selection_criteria:
    AL_class = ActiveLearningPipeline(model=model,
                                      test_indices=test_indices,
                                      available_pool_indices=available_pool_indices,
                                      train_indices=train_indices,
                                      selection_criterion=criterion,
                                      iterations=iterations,
                                      budget_per_iter=budget_per_iter,
                                      num_epochs=num_epoch)
    accuracy_scores_dict[criterion] = AL_class.run_pipeline()
generate_plot(accuracy_scores_dict)
# Out:
# --------- Number of Iteration 0 ---------
# /tmp/ipykernel_84042/686122032.py:81: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   labels = torch.tensor(labels).to(device)
# Epoch [1/15], Loss: 2.0872, Accuracy: 0.1000
# /tmp/ipykernel_84042/686122032.py:121: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   labels = torch.tensor(labels).to(device)
# Epoch [2/15], Loss: 2.0654, Accuracy: 0.0500
# Epoch [3/15], Loss: 2.0092, Accuracy: 0.3167
# Epoch [4/15], Loss: 1.9652, Accuracy: 0.5000
# Epoch [5/15], Loss: 1.9122, Accuracy: 0.3000
# Epoch [6/15], Loss: 1.8605, Accuracy: 0.2167
# Epoch [7/15], Loss: 1.8176, Accuracy: 0.2667
# Epoch [8/15], Loss: 1.7911, Accuracy: 0.3500
# Epoch [9/15], Loss: 1.7706, Accuracy: 0.5000
# Epoch [10/15], Loss: 1.7010, Accuracy: 0.6667
# Epoch [11/15], Loss: 1.6541, Accuracy: 0.8333
# Epoch [12/15], Loss: 1.6372, Accuracy: 0.8167
# Epoch [13/15], Loss: 1.6492, Accuracy: 0.8167
# Epoch [14/15], Loss: 1.5522, Accuracy: 0.8833
# Epoch [15/15], Loss: 1.5343, Accuracy: 0.9000
# ------------------------------------------------------------
# /tmp/ipykernel_84042/686122032.py:149: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   labels = torch.tensor(labels).to(device)
# --------- Number of Iteration 1 ---------
# Epoch [1/15], Loss: 1.7999, Accuracy: 0.6000
# Epoch [2/15], Loss: 1.7599, Accuracy: 0.6167
# Epoch [3/15], Loss: 1.7269, Accuracy: 0.6667
# Epoch [4/15], Loss: 1.7112, Accuracy: 0.7167
# Epoch [5/15], Loss: 1.6400, Accuracy: 0.7167
# Epoch [6/15], Loss: 1.6590, Accuracy: 0.6917
# Epoch [7/15], Loss: 1.6104, Accuracy: 0.7083
# Epoch [8/15], Loss: 1.6406, Accuracy: 0.7500
# Epoch [9/15], Loss: 1.5559, Accuracy: 0.7917
# Epoch [10/15], Loss: 1.5494, Accuracy: 0.7833
# Epoch [11/15], Loss: 1.5377, Accuracy: 0.7750
# Epoch [12/15], Loss: 1.5443, Accuracy: 0.8167
# Epoch [13/15], Loss: 1.5427, Accuracy: 0.7917
# Epoch [14/15], Loss: 1.5348, Accuracy: 0.8167
# Epoch [15/15], Loss: 1.4571, Accuracy: 0.8667
# ------------------------------------------------------------
# --------- Number of Iteration 2 ---------
# Epoch [1/15], Loss: 1.5713, Accuracy: 0.7444
# Epoch [2/15], Loss: 1.5715, Accuracy: 0.7222
# Epoch [3/15], Loss: 1.5321, Accuracy: 0.7667
# Epoch [4/15], Loss: 1.5343, Accuracy: 0.7500
# Epoch [5/15], Loss: 1.5424, Accuracy: 0.7833
# Epoch [6/15], Loss: 1.5347, Accuracy: 0.7222
# Epoch [7/15], Loss: 1.4756, Accuracy: 0.7944
# Epoch [8/15], Loss: 1.4565, Accuracy: 0.8278
# Epoch [9/15], Loss: 1.4477, Accuracy: 0.8167
# Epoch [10/15], Loss: 1.4377, Accuracy: 0.8611
# Epoch [11/15], Loss: 1.4373, Accuracy: 0.8111
# Epoch [12/15], Loss: 1.4055, Accuracy: 0.8611
# Epoch [13/15], Loss: 1.4061, Accuracy: 0.8556
# Epoch [14/15], Loss: 1.3969, Accuracy: 0.8667
# Epoch [15/15], Loss: 1.3895, Accuracy: 0.8611
# ------------------------------------------------------------
# --------- Number of Iteration 3 ---------
# Epoch [1/15], Loss: 1.4938, Accuracy: 0.7792
# Epoch [2/15], Loss: 1.4943, Accuracy: 0.7750
# Epoch [3/15], Loss: 1.4728, Accuracy: 0.7708
# Epoch [4/15], Loss: 1.4605, Accuracy: 0.8000
# Epoch [5/15], Loss: 1.4662, Accuracy: 0.7750
# Epoch [6/15], Loss: 1.4384, Accuracy: 0.8458
# Epoch [7/15], Loss: 1.4493, Accuracy: 0.8292
# Epoch [8/15], Loss: 1.4382, Accuracy: 0.8458
# Epoch [9/15], Loss: 1.4338, Accuracy: 0.8333
# Epoch [10/15], Loss: 1.4120, Accuracy: 0.8667
# Epoch [11/15], Loss: 1.4171, Accuracy: 0.8583
# Epoch [12/15], Loss: 1.4274, Accuracy: 0.8500
# Epoch [13/15], Loss: 1.4170, Accuracy: 0.8625
# Epoch [14/15], Loss: 1.4016, Accuracy: 0.8833
# Epoch [15/15], Loss: 1.4013, Accuracy: 0.8917
# ------------------------------------------------------------
# --------- Number of Iteration 4 ---------
# Epoch [1/15], Loss: 1.5650, Accuracy: 0.7233
# Epoch [2/15], Loss: 1.5511, Accuracy: 0.6767
# Epoch [3/15], Loss: 1.5508, Accuracy: 0.7333
# Epoch [4/15], Loss: 1.5445, Accuracy: 0.7533
# Epoch [5/15], Loss: 1.5114, Accuracy: 0.7333
# Epoch [6/15], Loss: 1.5088, Accuracy: 0.7733
# Epoch [7/15], Loss: 1.4762, Accuracy: 0.7700
# Epoch [8/15], Loss: 1.4815, Accuracy: 0.7600
# Epoch [9/15], Loss: 1.5029, Accuracy: 0.7533
# Epoch [10/15], Loss: 1.4554, Accuracy: 0.7700
# Epoch [11/15], Loss: 1.4676, Accuracy: 0.7933
# Epoch [12/15], Loss: 1.4633, Accuracy: 0.8000
# Epoch [13/15], Loss: 1.4739, Accuracy: 0.7933
# Epoch [14/15], Loss: 1.4294, Accuracy: 0.8300
# Epoch [15/15], Loss: 1.4764, Accuracy: 0.8267
# ------------------------------------------------------------
# --------- Number of Iteration 5 ---------
# Epoch [1/15], Loss: 1.5789, Accuracy: 0.6917
# Epoch [2/15], Loss: 1.5752, Accuracy: 0.7639
# Epoch [3/15], Loss: 1.5206, Accuracy: 0.7778
# Epoch [4/15], Loss: 1.5167, Accuracy: 0.7972
# Epoch [5/15], Loss: 1.5027, Accuracy: 0.8028
# Epoch [6/15], Loss: 1.4970, Accuracy: 0.7611
# Epoch [7/15], Loss: 1.4995, Accuracy: 0.8000
# Epoch [8/15], Loss: 1.5269, Accuracy: 0.7250
# Epoch [9/15], Loss: 1.4799, Accuracy: 0.8250
# Epoch [10/15], Loss: 1.4466, Accuracy: 0.8222
# Epoch [11/15], Loss: 1.4669, Accuracy: 0.8139
# Epoch [12/15], Loss: 1.4666, Accuracy: 0.8194
# Epoch [13/15], Loss: 1.4411, Accuracy: 0.8444
# Epoch [14/15], Loss: 1.4284, Accuracy: 0.8028
# Epoch [15/15], Loss: 1.4309, Accuracy: 0.8417
# ------------------------------------------------------------
# --------- Number of Iteration 6 ---------
# Epoch [1/15], Loss: 1.4755, Accuracy: 0.7976
# Epoch [2/15], Loss: 1.5064, Accuracy: 0.7714
# Epoch [3/15], Loss: 1.4574, Accuracy: 0.8286
# Epoch [4/15], Loss: 1.4721, Accuracy: 0.7738
# Epoch [5/15], Loss: 1.4621, Accuracy: 0.7976
# Epoch [6/15], Loss: 1.4706, Accuracy: 0.7905
# Epoch [7/15], Loss: 1.5668, Accuracy: 0.6429
# Epoch [8/15], Loss: 1.5653, Accuracy: 0.6214
# Epoch [9/15], Loss: 1.5354, Accuracy: 0.7381
# Epoch [10/15], Loss: 1.5530, Accuracy: 0.6405
# Epoch [11/15], Loss: 1.4379, Accuracy: 0.8024
# Epoch [12/15], Loss: 1.4432, Accuracy: 0.7762
# Epoch [13/15], Loss: 1.4622, Accuracy: 0.7214
# Epoch [14/15], Loss: 1.4591, Accuracy: 0.8214
# Epoch [15/15], Loss: 1.4325, Accuracy: 0.8238
# ------------------------------------------------------------
# --------- Number of Iteration 7 ---------
# Epoch [1/15], Loss: 1.5076, Accuracy: 0.7667
# Epoch [2/15], Loss: 1.4711, Accuracy: 0.7896
# Epoch [3/15], Loss: 1.4854, Accuracy: 0.7937
# Epoch [4/15], Loss: 1.4786, Accuracy: 0.7937
# Epoch [5/15], Loss: 1.4591, Accuracy: 0.8125
# Epoch [6/15], Loss: 1.4584, Accuracy: 0.8083
# Epoch [7/15], Loss: 1.4495, Accuracy: 0.8312
# Epoch [8/15], Loss: 1.4593, Accuracy: 0.8187
# Epoch [9/15], Loss: 1.4335, Accuracy: 0.8312
# Epoch [10/15], Loss: 1.4619, Accuracy: 0.8104
# Epoch [11/15], Loss: 1.4599, Accuracy: 0.8063
# Epoch [12/15], Loss: 1.4658, Accuracy: 0.8063
# Epoch [13/15], Loss: 1.4390, Accuracy: 0.8354
# Epoch [14/15], Loss: 1.4391, Accuracy: 0.8354
# Epoch [15/15], Loss: 1.4378, Accuracy: 0.8458
# ------------------------------------------------------------
# --------- Number of Iteration 8 ---------
# Epoch [1/15], Loss: 1.5148, Accuracy: 0.7778
# Epoch [2/15], Loss: 1.4881, Accuracy: 0.8204
# Epoch [3/15], Loss: 1.4795, Accuracy: 0.8185
# Epoch [4/15], Loss: 1.4887, Accuracy: 0.8074
# Epoch [5/15], Loss: 1.4741, Accuracy: 0.8037
# Epoch [6/15], Loss: 1.4659, Accuracy: 0.8278
# Epoch [7/15], Loss: 1.4630, Accuracy: 0.8444
# Epoch [8/15], Loss: 1.4653, Accuracy: 0.8019
# Epoch [9/15], Loss: 1.4409, Accuracy: 0.8481
# Epoch [10/15], Loss: 1.4459, Accuracy: 0.8352
# Epoch [11/15], Loss: 1.4521, Accuracy: 0.8259
# Epoch [12/15], Loss: 1.4494, Accuracy: 0.8389
# Epoch [13/15], Loss: 1.4320, Accuracy: 0.8704
# Epoch [14/15], Loss: 1.4260, Accuracy: 0.8537
# Epoch [15/15], Loss: 1.4314, Accuracy: 0.8537
# ------------------------------------------------------------
# --------- Number of Iteration 9 ---------
# Epoch [1/15], Loss: 1.5208, Accuracy: 0.7583
# Epoch [2/15], Loss: 1.5127, Accuracy: 0.7700
# Epoch [3/15], Loss: 1.4860, Accuracy: 0.7750
# Epoch [4/15], Loss: 1.5024, Accuracy: 0.7817
# Epoch [5/15], Loss: 1.4763, Accuracy: 0.8100
# Epoch [6/15], Loss: 1.4879, Accuracy: 0.7917
# Epoch [7/15], Loss: 1.4823, Accuracy: 0.7950
# Epoch [8/15], Loss: 1.4725, Accuracy: 0.8100
# Epoch [9/15], Loss: 1.4647, Accuracy: 0.8267
# Epoch [10/15], Loss: 1.4536, Accuracy: 0.8350
# Epoch [11/15], Loss: 1.4609, Accuracy: 0.8017
# Epoch [12/15], Loss: 1.4584, Accuracy: 0.8333
# Epoch [13/15], Loss: 1.4663, Accuracy: 0.7967
# Epoch [14/15], Loss: 1.4528, Accuracy: 0.8267
# Epoch [15/15], Loss: 1.4496, Accuracy: 0.8183
# ------------------------------------------------------------
# --------- Number of Iteration 10 ---------
# Epoch [1/15], Loss: 1.4939, Accuracy: 0.7970
# Epoch [2/15], Loss: 1.5055, Accuracy: 0.8091
# Epoch [3/15], Loss: 1.4879, Accuracy: 0.7909
# Epoch [4/15], Loss: 1.4937, Accuracy: 0.7833
# Epoch [5/15], Loss: 1.4769, Accuracy: 0.7939
# Epoch [6/15], Loss: 1.4806, Accuracy: 0.7742
# Epoch [7/15], Loss: 1.4734, Accuracy: 0.7924
# Epoch [8/15], Loss: 1.4795, Accuracy: 0.7939
# Epoch [9/15], Loss: 1.4651, Accuracy: 0.8167
# Epoch [10/15], Loss: 1.4553, Accuracy: 0.8348
# Epoch [11/15], Loss: 1.4549, Accuracy: 0.8242
# Epoch [12/15], Loss: 1.4335, Accuracy: 0.8591
# Epoch [13/15], Loss: 1.4404, Accuracy: 0.8288
# Epoch [14/15], Loss: 1.4473, Accuracy: 0.8303
# Epoch [15/15], Loss: 1.4487, Accuracy: 0.8409
# ------------------------------------------------------------
# --------- Number of Iteration 11 ---------
# Epoch [1/15], Loss: 1.5295, Accuracy: 0.7569
# Epoch [2/15], Loss: 1.5306, Accuracy: 0.7597
# Epoch [3/15], Loss: 1.5413, Accuracy: 0.6889
# Epoch [4/15], Loss: 1.5142, Accuracy: 0.7431
# Epoch [5/15], Loss: 1.5009, Accuracy: 0.7764
# Epoch [6/15], Loss: 1.5006, Accuracy: 0.7625
# Epoch [7/15], Loss: 1.5005, Accuracy: 0.7931
# Epoch [8/15], Loss: 1.4982, Accuracy: 0.7847
# Epoch [9/15], Loss: 1.4887, Accuracy: 0.7611
# Epoch [10/15], Loss: 1.5002, Accuracy: 0.7611
# Epoch [11/15], Loss: 1.4872, Accuracy: 0.7861
# Epoch [12/15], Loss: 1.4863, Accuracy: 0.8194
# Epoch [13/15], Loss: 1.4735, Accuracy: 0.7833
# Epoch [14/15], Loss: 1.5046, Accuracy: 0.7458
# Epoch [15/15], Loss: 1.4706, Accuracy: 0.8014
# ------------------------------------------------------------
# --------- Number of Iteration 12 ---------
# Epoch [1/15], Loss: 1.5069, Accuracy: 0.7192
# Epoch [2/15], Loss: 1.4966, Accuracy: 0.7667
# Epoch [3/15], Loss: 1.4978, Accuracy: 0.7705
# Epoch [4/15], Loss: 1.4985, Accuracy: 0.7603
# Epoch [5/15], Loss: 1.5087, Accuracy: 0.7744
# Epoch [6/15], Loss: 1.5230, Accuracy: 0.7538
# Epoch [7/15], Loss: 1.4962, Accuracy: 0.7769
# Epoch [8/15], Loss: 1.4487, Accuracy: 0.8269
# Epoch [9/15], Loss: 1.4629, Accuracy: 0.8026
# Epoch [10/15], Loss: 1.4661, Accuracy: 0.8103
# Epoch [11/15], Loss: 1.4664, Accuracy: 0.7769
# Epoch [12/15], Loss: 1.4719, Accuracy: 0.8179
# Epoch [13/15], Loss: 1.4557, Accuracy: 0.8013
# Epoch [14/15], Loss: 1.4534, Accuracy: 0.8154
# Epoch [15/15], Loss: 1.4753, Accuracy: 0.7885
# ------------------------------------------------------------
# --------- Number of Iteration 13 ---------
# Epoch [1/15], Loss: 1.4932, Accuracy: 0.7500
# Epoch [2/15], Loss: 1.5153, Accuracy: 0.7298
# Epoch [3/15], Loss: 1.5108, Accuracy: 0.7345
# Epoch [4/15], Loss: 1.4850, Accuracy: 0.7762
# Epoch [5/15], Loss: 1.4992, Accuracy: 0.7905
# Epoch [6/15], Loss: 1.5151, Accuracy: 0.7369
# Epoch [7/15], Loss: 1.5091, Accuracy: 0.7512
# Epoch [8/15], Loss: 1.4936, Accuracy: 0.7548
# Epoch [9/15], Loss: 1.4765, Accuracy: 0.8048
# Epoch [10/15], Loss: 1.4775, Accuracy: 0.7881
# Epoch [11/15], Loss: 1.4569, Accuracy: 0.8071
# Epoch [12/15], Loss: 1.4671, Accuracy: 0.7774
# Epoch [13/15], Loss: 1.4641, Accuracy: 0.8071
# Epoch [14/15], Loss: 1.4795, Accuracy: 0.7881
# Epoch [15/15], Loss: 1.4724, Accuracy: 0.7869
# ------------------------------------------------------------
# --------- Number of Iteration 14 ---------
# Epoch [1/15], Loss: 1.5331, Accuracy: 0.7411
# Epoch [2/15], Loss: 1.5992, Accuracy: 0.5922
# Epoch [3/15], Loss: 1.6060, Accuracy: 0.6078
# Epoch [4/15], Loss: 1.5320, Accuracy: 0.7322
# Epoch [5/15], Loss: 1.6105, Accuracy: 0.5744
# Epoch [6/15], Loss: 1.5210, Accuracy: 0.7233
# Epoch [7/15], Loss: 1.5334, Accuracy: 0.7267
# Epoch [8/15], Loss: 1.5365, Accuracy: 0.7267
# Epoch [9/15], Loss: 1.5123, Accuracy: 0.7378
# Epoch [10/15], Loss: 1.4963, Accuracy: 0.7522
# Epoch [11/15], Loss: 1.6178, Accuracy: 0.5267
# Epoch [12/15], Loss: 1.5936, Accuracy: 0.5633
# Epoch [13/15], Loss: 1.5532, Accuracy: 0.7378
# Epoch [14/15], Loss: 1.6212, Accuracy: 0.6144
# Epoch [15/15], Loss: 1.5612, Accuracy: 0.7467
# ------------------------------------------------------------
# --------- Number of Iteration 15 ---------
# Epoch [1/15], Loss: 1.4967, Accuracy: 0.7385
# Epoch [2/15], Loss: 1.4855, Accuracy: 0.7542
# Epoch [3/15], Loss: 1.4793, Accuracy: 0.7729
# Epoch [4/15], Loss: 1.4842, Accuracy: 0.7719
# Epoch [5/15], Loss: 1.4672, Accuracy: 0.7792
# Epoch [6/15], Loss: 1.4686, Accuracy: 0.7812
# Epoch [7/15], Loss: 1.4649, Accuracy: 0.7646
# Epoch [8/15], Loss: 1.4604, Accuracy: 0.7792
# Epoch [9/15], Loss: 1.4782, Accuracy: 0.7771
# Epoch [10/15], Loss: 1.4624, Accuracy: 0.7729
# Epoch [11/15], Loss: 1.4516, Accuracy: 0.7833
# Epoch [12/15], Loss: 1.4380, Accuracy: 0.8052
# Epoch [13/15], Loss: 1.4521, Accuracy: 0.7854
# Epoch [14/15], Loss: 1.4402, Accuracy: 0.7812
# Epoch [15/15], Loss: 1.4468, Accuracy: 0.7885
# ------------------------------------------------------------
# --------- Number of Iteration 16 ---------
# Epoch [1/15], Loss: 1.4963, Accuracy: 0.7343
# Epoch [2/15], Loss: 1.5003, Accuracy: 0.7539
# Epoch [3/15], Loss: 1.5171, Accuracy: 0.7363
# Epoch [4/15], Loss: 1.4808, Accuracy: 0.7588
# Epoch [5/15], Loss: 1.4801, Accuracy: 0.7627
# Epoch [6/15], Loss: 1.4689, Accuracy: 0.7745
# Epoch [7/15], Loss: 1.4696, Accuracy: 0.7755
# Epoch [8/15], Loss: 1.4558, Accuracy: 0.7676
# Epoch [9/15], Loss: 1.4763, Accuracy: 0.7529
# Epoch [10/15], Loss: 1.4618, Accuracy: 0.7569
# Epoch [11/15], Loss: 1.4424, Accuracy: 0.7961
# Epoch [12/15], Loss: 1.4548, Accuracy: 0.7765
# Epoch [13/15], Loss: 1.4495, Accuracy: 0.7892
# Epoch [14/15], Loss: 1.4435, Accuracy: 0.7833
# Epoch [15/15], Loss: 1.4338, Accuracy: 0.7882
# ------------------------------------------------------------
# --------- Number of Iteration 17 ---------
# Epoch [1/15], Loss: 1.4828, Accuracy: 0.7648
# Epoch [2/15], Loss: 1.4689, Accuracy: 0.7676
# Epoch [3/15], Loss: 1.4777, Accuracy: 0.7454
# Epoch [4/15], Loss: 1.4720, Accuracy: 0.7787
# Epoch [5/15], Loss: 1.4945, Accuracy: 0.7463
# Epoch [6/15], Loss: 1.4821, Accuracy: 0.7676
# Epoch [7/15], Loss: 1.4490, Accuracy: 0.7889
# Epoch [8/15], Loss: 1.4721, Accuracy: 0.7713
# Epoch [9/15], Loss: 1.4630, Accuracy: 0.7731
# Epoch [10/15], Loss: 1.4654, Accuracy: 0.7796
# Epoch [11/15], Loss: 1.4533, Accuracy: 0.7935
# Epoch [12/15], Loss: 1.4590, Accuracy: 0.7898
# Epoch [13/15], Loss: 1.4598, Accuracy: 0.7657
# Epoch [14/15], Loss: 1.4565, Accuracy: 0.7722
# Epoch [15/15], Loss: 1.4777, Accuracy: 0.7620
# ------------------------------------------------------------
# --------- Number of Iteration 18 ---------
# Epoch [1/15], Loss: 1.4882, Accuracy: 0.7570
# Epoch [2/15], Loss: 1.4712, Accuracy: 0.7640
# Epoch [3/15], Loss: 1.4731, Accuracy: 0.7702
# Epoch [4/15], Loss: 1.4859, Accuracy: 0.7535
# Epoch [5/15], Loss: 1.4541, Accuracy: 0.7798
# Epoch [6/15], Loss: 1.4675, Accuracy: 0.7825
# Epoch [7/15], Loss: 1.4623, Accuracy: 0.7798
# Epoch [8/15], Loss: 1.4568, Accuracy: 0.7886
# Epoch [9/15], Loss: 1.4654, Accuracy: 0.7912
# Epoch [10/15], Loss: 1.4493, Accuracy: 0.7982
# Epoch [11/15], Loss: 1.4582, Accuracy: 0.7807
# Epoch [12/15], Loss: 1.4508, Accuracy: 0.7930
# Epoch [13/15], Loss: 1.4430, Accuracy: 0.8053
# Epoch [14/15], Loss: 1.4365, Accuracy: 0.8132
# Epoch [15/15], Loss: 1.4532, Accuracy: 0.7895
# ------------------------------------------------------------
# --------- Number of Iteration 19 ---------
# Epoch [1/15], Loss: 1.5084, Accuracy: 0.7258
# Epoch [2/15], Loss: 1.4782, Accuracy: 0.7533
# Epoch [3/15], Loss: 1.4715, Accuracy: 0.7675
# Epoch [4/15], Loss: 1.4806, Accuracy: 0.7508
# Epoch [5/15], Loss: 1.4643, Accuracy: 0.7742
# Epoch [6/15], Loss: 1.4722, Accuracy: 0.7733
# Epoch [7/15], Loss: 1.4687, Accuracy: 0.7733
# Epoch [8/15], Loss: 1.4604, Accuracy: 0.7842
# Epoch [9/15], Loss: 1.4461, Accuracy: 0.7883
# Epoch [10/15], Loss: 1.4803, Accuracy: 0.7600
# Epoch [11/15], Loss: 1.4549, Accuracy: 0.7842
# Epoch [12/15], Loss: 1.4569, Accuracy: 0.7833
# Epoch [13/15], Loss: 1.4575, Accuracy: 0.7917
# Epoch [14/15], Loss: 1.4549, Accuracy: 0.7925
# Epoch [15/15], Loss: 1.4456, Accuracy: 0.7942
# ------------------------------------------------------------

# %%
accuracy_scores_dict
# Out:
# defaultdict(list,
#             {'random': [0.5257936507936508,
#               0.5634920634920635,
#               0.5601851851851851,
#               0.5912698412698413,
#               0.6031746031746031,
#               0.6177248677248677,
#               0.6362433862433862,
#               0.6408730158730158,
#               0.6587301587301587,
#               0.6693121693121693,
#               0.621031746031746,
#               0.6421957671957672,
#               0.6461640211640212,
#               0.6593915343915343,
#               0.6355820105820106,
#               0.6402116402116402,
#               0.6316137566137566,
#               0.662037037037037,
#               0.6362433862433862,
#               0.6395502645502645]})
